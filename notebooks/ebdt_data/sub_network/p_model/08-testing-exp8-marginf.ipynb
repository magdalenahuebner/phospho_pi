# %% [markdown]
# #### Prerequesites:
# * Define schema (make figure)
# * Define structure (make figure)
# * Define schema class in python (src/models/model_schemata.py)
# * Convert schema + structure into model template (models/templates/p_model.pl)
#
# #### Procedure:
# * Load data
# * Adjust model script for lfi accordingly
# * Create evidence file (if I don't need different evidence files, move to builmodel notebook)
# * LFI

# %% [markdown]
# Multiple instances, 1 pst, X enzymes, one sample per instance, multiple enzymes per instance, test how many enzymes can have in one instances, how computing time depends on N p::f for 60 samples

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os
import pickle
import random

from src.models import model_schemata as schema
from src.models import build_model as build
from src.models import parameter_learning as lfi
from src.models import inference as inf
from src.visualization import visualize as viz

# %%
os.chdir('/Users/magdalena/OneDrive - Queen Mary, University of London/bezzlab/research/projects/phospho_pi/')
# os.chdir('/home/mhuebner/Desktop/bezzlab/research/projects/phospho_pi/')

# %% [markdown]
# #### Inference (I)

# %%
# reading csv from files into dict
data = {}
data['e_ksea'] = pd.read_csv('data/processed/ebdt_data/sub_network_p/e_ksea.csv')
data['p_fc'] = pd.read_csv('data/processed/ebdt_data/sub_network_p/p_fc.csv')

# %%
# getting sample names (union of all samples in all datasets)
samples = list(set(data['e_ksea']['sample']).union(set(data['p_fc']['sample'])))
samples.sort()
# sample x% of samples randomly without replacement with seed
random.seed(612)
train = random.sample(samples, int(len(samples)*0.8))
test = [x for x in samples if x not in train]
print(test)
# filter data
testing_data = {}
testing_data['e_ksea'] = data['e_ksea'][data['e_ksea']['sample'].isin(test)].reset_index(drop=True)
testing_data['p_fc'] = data['p_fc'][data['p_fc']['sample'].isin(test)].reset_index(drop=True)
# Out:
# ['AZD6738', 'Dasatinib', 'GO6983', 'GSK690693', 'KD025', 'KN62', 'MK2206', 'PD153035', 'PF4708671', 'PIK294', 'Tofacitinib', 'Ulixertinib', 'Vemurafenib']

# %%
# Adding evidence
model_inference = 'models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl'

# %% [markdown]
# #### Inferring p_occupancy

# %% [markdown]
# Adding queries

# %%
sample_ids = testing_data['p_fc']['sample'].unique().tolist()
phosphosites = testing_data['p_fc']['phosphosite'].unique().tolist()
queries = inf.generate_queries(schema.POccupancyPredicate, sample_ids=sample_ids, phosphosites=phosphosites)
len(queries)
# Out:
# 117

# %%
queries[:10]
# Out:
# ['query(p_occupancy("ABI1(Y213)", "PD153035", _)).',
#  'query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).',
#  'query(p_occupancy("ATF1(S198)", "PD153035", _)).',
#  'query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).',
#  'query(p_occupancy("HIPK2(Y361)", "PD153035", _)).',
#  'query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).',
#  'query(p_occupancy("PXN(Y118)", "PD153035", _)).',
#  'query(p_occupancy("PXN(Y88)", "PD153035", _)).',
#  'query(p_occupancy("RBM39(Y95)", "PD153035", _)).',
#  'query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).']

# %% [markdown]
# Adding evidence (phosphosite and relevant enzymes)

# %%
# Mapping data to Problog predicates
predicates = {}
predicates['p_fc'] = schema.PFoldChangePredicate()
predicates['p_fc'].add_data(testing_data['p_fc'], 'phosphosite', 'sample', 'value')
predicates['e_ksea'] = schema.EKseaPredicate()
predicates['e_ksea'].add_data(testing_data['e_ksea'], 'enzyme', 'sample', 'value')

# %%
data['es_interaction'] = pd.read_csv('data/processed/ebdt_data/sub_network_p/es_interaction.csv')

# %%
evidence_dict = {}
for s in sample_ids:
    evidence_dict[s] = {}
    for p in phosphosites:
        enzymes = data['es_interaction']['enzyme'][data['es_interaction']['phosphosite'] == p].tolist()
        evid_generator = build.ProblogStatementGenerator(predicates['e_ksea'])
        evidence_e = []
        for e in enzymes:
            evidence_e.extend(evid_generator.generate_facts(build.EvidenceTemplate, select=[s, e]))
        evid_generator = build.ProblogStatementGenerator(predicates['p_fc'])
        evidence_p = evid_generator.generate_facts(build.EvidenceTemplate, select=[s, p])
        evidence_dict[s][p] = evidence_e + evidence_p

# %%
# make evidence_dict['AZD5438'] into list
evidence_list = []
for s in evidence_dict.keys():
    for p in evidence_dict[s]:
        evidence_list.append(evidence_dict[s][p])
evidence_list[:10]
# Out:
# [['evidence(e_ksea("ABL1", "PD153035", inc)).',
#   'evidence(p_fc("ABI1(Y213)", "PD153035", inc)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(p_fc("ANXA2P2(Y24)", "PD153035", inc)).'],
#  ['evidence(e_ksea("HIPK2", "PD153035", dec)).',
#   'evidence(p_fc("ATF1(S198)", "PD153035", dec)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(p_fc("BCLAF1(Y284)", "PD153035", inc)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(e_ksea("HIPK2", "PD153035", dec)).',
#   'evidence(p_fc("HIPK2(Y361)", "PD153035", inc)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(p_fc("PTTG1IP(Y174)", "PD153035", dec)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(e_ksea("ABL1", "PD153035", inc)).',
#   'evidence(e_ksea("PTK2", "PD153035", dec)).',
#   'evidence(e_ksea("PTPRG", "PD153035", dec)).',
#   'evidence(e_ksea("FYN", "PD153035", dec)).',
#   'evidence(e_ksea("PTK6", "PD153035", dec)).',
#   'evidence(p_fc("PXN(Y118)", "PD153035", dec)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(e_ksea("PTPRR", "PD153035", inc)).',
#   'evidence(p_fc("PXN(Y88)", "PD153035", dec)).'],
#  ['evidence(e_ksea("ABL1", "PD153035", inc)).',
#   'evidence(p_fc("RBM39(Y95)", "PD153035", inc)).'],
#  ['evidence(e_ksea("ABL1", "Tofacitinib", inc)).',
#   'evidence(p_fc("ABI1(Y213)", "Tofacitinib", dec)).']]

# %%
inference_output = 'models/ebdt_data/sub_network/p_model/inference_log_8.txt'
inf_data_dict = inf.infer_marginf(model_inference, queries, inference_output, evidence=evidence_list)
pickle.dump(inf_data_dict, open('models/ebdt_data/sub_network/p_model/testing_relepev_exp8_5i.pkl', 'wb'))
# Out:
# ['query(p_occupancy("ABI1(Y213)", "PD153035", _)).']
# 1/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0225s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0196s
# [INFO] Total time: 2.2020s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "PD153035", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).']
# 2/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0241s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0194s
# [INFO] Total time: 2.1917s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "PD153035", _)).']
# 3/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0220s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0186s
# [INFO] Total time: 2.2355s
# Finished inference (['query(p_occupancy("ATF1(S198)", "PD153035", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).']
# 4/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0226s
# [INFO] Cycle breaking: 0.0030s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0200s
# [INFO] Total time: 2.0173s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "PD153035", _)).']
# 5/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0349s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0291s
# [INFO] Total time: 2.2194s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "PD153035", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).']
# 6/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0223s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0192s
# [INFO] Total time: 2.0458s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "PD153035", _)).']
# 7/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0606s
# [INFO] Cycle breaking: 0.0071s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.3661s
# [INFO] Total time: 4.5175s
# Finished inference (['query(p_occupancy("PXN(Y118)", "PD153035", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "PD153035", _)).']
# 8/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0312s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0256s
# [INFO] Total time: 2.1397s
# Finished inference (['query(p_occupancy("PXN(Y88)", "PD153035", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "PD153035", _)).']
# 9/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0239s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0204s
# [INFO] Total time: 1.9620s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "PD153035", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).']
# 10/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0253s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.1123s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Tofacitinib", _)).']
# 11/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0225s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0200s
# [INFO] Total time: 2.3573s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Tofacitinib", _)).']
# 12/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0267s
# [INFO] Cycle breaking: 0.0042s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0315s
# [INFO] Total time: 2.9879s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Tofacitinib", _)).']
# 13/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0499s
# [INFO] Cycle breaking: 0.0041s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0300s
# [INFO] Total time: 3.1369s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Tofacitinib", _)).']
# 14/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0436s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0338s
# [INFO] Total time: 3.3866s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Tofacitinib", _)).']
# 15/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0465s
# [INFO] Cycle breaking: 0.0099s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0367s
# [INFO] Total time: 3.3706s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Tofacitinib", _)).']
# 16/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0783s
# [INFO] Cycle breaking: 0.0080s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 1.9746s
# [INFO] Total time: 7.0109s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Tofacitinib", _)).']
# 17/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0454s
# [INFO] Cycle breaking: 0.0047s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0424s
# [INFO] Total time: 2.8688s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Tofacitinib", _)).']
# 18/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0354s
# [INFO] Cycle breaking: 0.0048s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0214s
# [INFO] Total time: 3.0424s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "PIK294", _)).']
# 19/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0265s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0213s
# [INFO] Total time: 2.4429s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "PIK294", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "PIK294", _)).']
# 20/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0239s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0242s
# [INFO] Total time: 2.7868s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "PIK294", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "PIK294", _)).']
# 21/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0242s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0187s
# [INFO] Total time: 2.4451s
# Finished inference (['query(p_occupancy("ATF1(S198)", "PIK294", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "PIK294", _)).']
# 22/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0233s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0188s
# [INFO] Total time: 2.5788s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "PIK294", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "PIK294", _)).']
# 23/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0343s
# [INFO] Cycle breaking: 0.0030s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0300s
# [INFO] Total time: 2.5239s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "PIK294", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "PIK294", _)).']
# 24/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0233s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0204s
# [INFO] Total time: 2.9050s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "PIK294", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "PIK294", _)).']
# 25/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.1140s
# [INFO] Cycle breaking: 0.0105s
# [INFO] Clark's completion: 0.0008s
# [INFO] DSharp compilation: 1.8387s
# [INFO] Total time: 5.7541s
# Finished inference (['query(p_occupancy("PXN(Y118)", "PIK294", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "PIK294", _)).']
# 26/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0332s
# [INFO] Cycle breaking: 0.0030s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0289s
# [INFO] Total time: 2.3358s
# Finished inference (['query(p_occupancy("PXN(Y88)", "PIK294", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "PIK294", _)).']
# 27/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0249s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0224s
# [INFO] Total time: 2.2021s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "PIK294", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Ulixertinib", _)).']
# 28/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0287s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0197s
# [INFO] Total time: 2.6300s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Ulixertinib", _)).']
# 29/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0273s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0297s
# [INFO] Total time: 2.5032s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Ulixertinib", _)).']
# 30/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0285s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0221s
# [INFO] Total time: 2.4724s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Ulixertinib", _)).']
# 31/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0233s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0221s
# [INFO] Total time: 2.5879s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Ulixertinib", _)).']
# 32/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0474s
# [INFO] Cycle breaking: 0.0071s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0403s
# [INFO] Total time: 2.7955s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Ulixertinib", _)).']
# 33/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0316s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.7713s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Ulixertinib", _)).']
# 34/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0769s
# [INFO] Cycle breaking: 0.0112s
# [INFO] Clark's completion: 0.0007s
# [INFO] DSharp compilation: 1.6711s
# [INFO] Total time: 5.8209s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Ulixertinib", _)).']
# 35/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0448s
# [INFO] Cycle breaking: 0.0062s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0305s
# [INFO] Total time: 2.6811s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Ulixertinib", _)).']
# 36/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0253s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0219s
# [INFO] Total time: 2.5472s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "GSK690693", _)).']
# 37/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0273s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0230s
# [INFO] Total time: 2.5689s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "GSK690693", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "GSK690693", _)).']
# 38/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0334s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0241s
# [INFO] Total time: 2.6246s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "GSK690693", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "GSK690693", _)).']
# 39/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0249s
# [INFO] Cycle breaking: 0.0034s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0208s
# [INFO] Total time: 2.5656s
# Finished inference (['query(p_occupancy("ATF1(S198)", "GSK690693", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "GSK690693", _)).']
# 40/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0242s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0291s
# [INFO] Total time: 2.3461s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "GSK690693", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "GSK690693", _)).']
# 41/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0365s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0283s
# [INFO] Total time: 2.5463s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "GSK690693", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "GSK690693", _)).']
# 42/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0258s
# [INFO] Cycle breaking: 0.0038s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0216s
# [INFO] Total time: 2.4208s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "GSK690693", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "GSK690693", _)).']
# 43/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0685s
# [INFO] Cycle breaking: 0.0078s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.6673s
# [INFO] Total time: 5.5934s
# Finished inference (['query(p_occupancy("PXN(Y118)", "GSK690693", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "GSK690693", _)).']
# 44/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0427s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0365s
# [INFO] Total time: 2.6462s
# Finished inference (['query(p_occupancy("PXN(Y88)", "GSK690693", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "GSK690693", _)).']
# 45/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0314s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0206s
# [INFO] Total time: 2.4349s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "GSK690693", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "KN62", _)).']
# 46/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0327s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0253s
# [INFO] Total time: 2.6228s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "KN62", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "KN62", _)).']
# 47/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0262s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0221s
# [INFO] Total time: 2.7415s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "KN62", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "KN62", _)).']
# 48/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0239s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0247s
# [INFO] Total time: 2.4965s
# Finished inference (['query(p_occupancy("ATF1(S198)", "KN62", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "KN62", _)).']
# 49/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0321s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0255s
# [INFO] Total time: 2.5553s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "KN62", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "KN62", _)).']
# 50/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0361s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0292s
# [INFO] Total time: 2.4928s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "KN62", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "KN62", _)).']
# 51/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0244s
# [INFO] Cycle breaking: 0.0038s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0302s
# [INFO] Total time: 2.7094s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "KN62", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "KN62", _)).']
# 52/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0918s
# [INFO] Cycle breaking: 0.0086s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 1.7955s
# [INFO] Total time: 6.2132s
# Finished inference (['query(p_occupancy("PXN(Y118)", "KN62", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "KN62", _)).']
# 53/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0413s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0339s
# [INFO] Total time: 3.1143s
# Finished inference (['query(p_occupancy("PXN(Y88)", "KN62", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "KN62", _)).']
# 54/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0276s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0250s
# [INFO] Total time: 3.1937s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "KN62", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "PF4708671", _)).']
# 55/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0345s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0243s
# [INFO] Total time: 2.9871s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "PF4708671", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "PF4708671", _)).']
# 56/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0312s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0218s
# [INFO] Total time: 2.9081s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "PF4708671", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "PF4708671", _)).']
# 57/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0337s
# [INFO] Cycle breaking: 0.0040s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0221s
# [INFO] Total time: 2.6321s
# Finished inference (['query(p_occupancy("ATF1(S198)", "PF4708671", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "PF4708671", _)).']
# 58/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0274s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0221s
# [INFO] Total time: 2.6526s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "PF4708671", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "PF4708671", _)).']
# 59/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0421s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0279s
# [INFO] Total time: 2.6020s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "PF4708671", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "PF4708671", _)).']
# 60/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0234s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0239s
# [INFO] Total time: 2.2599s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "PF4708671", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "PF4708671", _)).']
# 61/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0701s
# [INFO] Cycle breaking: 0.0081s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 1.6165s
# [INFO] Total time: 5.3759s
# Finished inference (['query(p_occupancy("PXN(Y118)", "PF4708671", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "PF4708671", _)).']
# 62/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0355s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0336s
# [INFO] Total time: 2.2588s
# Finished inference (['query(p_occupancy("PXN(Y88)", "PF4708671", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "PF4708671", _)).']
# 63/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0309s
# [INFO] Cycle breaking: 0.0041s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0255s
# [INFO] Total time: 2.4613s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "PF4708671", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "AZD6738", _)).']
# 64/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0262s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0225s
# [INFO] Total time: 2.4089s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "AZD6738", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "AZD6738", _)).']
# 65/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0291s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0217s
# [INFO] Total time: 2.3900s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "AZD6738", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "AZD6738", _)).']
# 66/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0257s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0196s
# [INFO] Total time: 2.2938s
# Finished inference (['query(p_occupancy("ATF1(S198)", "AZD6738", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "AZD6738", _)).']
# 67/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0278s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0216s
# [INFO] Total time: 2.3557s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "AZD6738", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "AZD6738", _)).']
# 68/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0312s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0260s
# [INFO] Total time: 2.2529s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "AZD6738", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "AZD6738", _)).']
# 69/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0250s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0219s
# [INFO] Total time: 2.1348s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "AZD6738", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "AZD6738", _)).']
# 70/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0841s
# [INFO] Cycle breaking: 0.0100s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 1.4937s
# [INFO] Total time: 4.9766s
# Finished inference (['query(p_occupancy("PXN(Y118)", "AZD6738", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "AZD6738", _)).']
# 71/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0340s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0365s
# [INFO] Total time: 2.2997s
# Finished inference (['query(p_occupancy("PXN(Y88)", "AZD6738", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "AZD6738", _)).']
# 72/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0243s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0203s
# [INFO] Total time: 2.3705s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "AZD6738", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Dasatinib", _)).']
# 73/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0239s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.4130s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Dasatinib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Dasatinib", _)).']
# 74/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0247s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0244s
# [INFO] Total time: 2.3249s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Dasatinib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Dasatinib", _)).']
# 75/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0278s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0211s
# [INFO] Total time: 2.4542s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Dasatinib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Dasatinib", _)).']
# 76/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0261s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0208s
# [INFO] Total time: 2.6444s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Dasatinib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Dasatinib", _)).']
# 77/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0309s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0296s
# [INFO] Total time: 2.2606s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Dasatinib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Dasatinib", _)).']
# 78/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0284s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0184s
# [INFO] Total time: 2.3928s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Dasatinib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Dasatinib", _)).']
# 79/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0662s
# [INFO] Cycle breaking: 0.0079s
# [INFO] Clark's completion: 0.0008s
# [INFO] DSharp compilation: 1.4789s
# [INFO] Total time: 5.0503s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Dasatinib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Dasatinib", _)).']
# 80/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0335s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0301s
# [INFO] Total time: 2.5265s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Dasatinib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Dasatinib", _)).']
# 81/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0238s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0204s
# [INFO] Total time: 2.5368s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Dasatinib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "KD025", _)).']
# 82/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0295s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0225s
# [INFO] Total time: 2.2238s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "KD025", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "KD025", _)).']
# 83/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0288s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0216s
# [INFO] Total time: 2.4180s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "KD025", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "KD025", _)).']
# 84/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0248s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# ...
# 90/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0265s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0217s
# [INFO] Total time: 2.1140s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "KD025", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Vemurafenib", _)).']
# 91/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0236s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0178s
# [INFO] Total time: 2.3371s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Vemurafenib", _)).']
# 92/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0273s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.3432s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Vemurafenib", _)).']
# 93/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0276s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0189s
# [INFO] Total time: 2.3784s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Vemurafenib", _)).']
# 94/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0252s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0236s
# [INFO] Total time: 2.3863s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Vemurafenib", _)).']
# 95/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0357s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0286s
# [INFO] Total time: 2.4595s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Vemurafenib", _)).']
# 96/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0268s
# [INFO] Cycle breaking: 0.0040s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0240s
# [INFO] Total time: 2.3580s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Vemurafenib", _)).']
# 97/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0744s
# [INFO] Cycle breaking: 0.0085s
# [INFO] Clark's completion: 0.0008s
# [INFO] DSharp compilation: 1.4804s
# [INFO] Total time: 4.9575s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Vemurafenib", _)).']
# 98/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0307s
# [INFO] Cycle breaking: 0.0048s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0281s
# [INFO] Total time: 2.3656s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Vemurafenib", _)).']
# 99/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0245s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0193s
# [INFO] Total time: 2.1603s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "GO6983", _)).']
# 100/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0265s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0221s
# [INFO] Total time: 2.3398s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "GO6983", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "GO6983", _)).']
# 101/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0299s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0188s
# [INFO] Total time: 2.1571s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "GO6983", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "GO6983", _)).']
# 102/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0221s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0192s
# [INFO] Total time: 2.0865s
# Finished inference (['query(p_occupancy("ATF1(S198)", "GO6983", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "GO6983", _)).']
# 103/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0212s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0211s
# [INFO] Total time: 2.0772s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "GO6983", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "GO6983", _)).']
# 104/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0350s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0352s
# [INFO] Total time: 2.2871s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "GO6983", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "GO6983", _)).']
# 105/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0231s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0191s
# [INFO] Total time: 2.3227s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "GO6983", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "GO6983", _)).']
# 106/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0678s
# [INFO] Cycle breaking: 0.0083s
# [INFO] Clark's completion: 0.0009s
# [INFO] DSharp compilation: 1.6062s
# [INFO] Total time: 5.1158s
# Finished inference (['query(p_occupancy("PXN(Y118)", "GO6983", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "GO6983", _)).']
# 107/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0353s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0284s
# [INFO] Total time: 2.3764s
# Finished inference (['query(p_occupancy("PXN(Y88)", "GO6983", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "GO6983", _)).']
# 108/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0249s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0199s
# [INFO] Total time: 2.3564s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "GO6983", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "MK2206", _)).']
# 109/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0212s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0187s
# [INFO] Total time: 2.1986s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "MK2206", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "MK2206", _)).']
# 110/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0220s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0214s
# [INFO] Total time: 2.2981s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "MK2206", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "MK2206", _)).']
# 111/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0218s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.4251s
# Finished inference (['query(p_occupancy("ATF1(S198)", "MK2206", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "MK2206", _)).']
# 112/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0274s
# [INFO] Cycle breaking: 0.0038s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0244s
# [INFO] Total time: 2.3227s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "MK2206", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "MK2206", _)).']
# 113/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0350s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0287s
# [INFO] Total time: 2.2578s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "MK2206", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "MK2206", _)).']
# 114/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0239s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0178s
# [INFO] Total time: 2.0675s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "MK2206", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "MK2206", _)).']
# 115/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0700s
# [INFO] Cycle breaking: 0.0095s
# [INFO] Clark's completion: 0.0008s
# [INFO] DSharp compilation: 1.5737s
# [INFO] Total time: 5.3725s
# Finished inference (['query(p_occupancy("PXN(Y118)", "MK2206", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "MK2206", _)).']
# 116/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0353s
# [INFO] Cycle breaking: 0.0040s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0278s
# [INFO] Total time: 2.2744s
# Finished inference (['query(p_occupancy("PXN(Y88)", "MK2206", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "MK2206", _)).']
# 117/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0284s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0193s
# [INFO] Total time: 2.1359s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "MK2206", _)).'])...

# %% [markdown]
# Adding evidence (relevant enzymes only)

# %%
data['es_interaction'] = pd.read_csv('data/processed/ebdt_data/sub_network_p/es_interaction.csv')

# %%
evidence_dict = {}
for s in sample_ids:
    evidence_dict[s] = {}
    for p in phosphosites:
        enzymes = data['es_interaction']['enzyme'][data['es_interaction']['phosphosite'] == p].tolist()
        evid_generator = build.ProblogStatementGenerator(predicates['e_ksea'])
        evidence_e = []
        for e in enzymes:
            evidence_e.extend(evid_generator.generate_facts(build.EvidenceTemplate, select=[s, e]))
        evidence_dict[s][p] = evidence_e

# %%
# make evidence_dict['AZD5438'] into list
evidence_list = []
for s in evidence_dict.keys():
    for p in evidence_dict[s]:
        evidence_list.append(evidence_dict[s][p])
evidence_list[:10]
# Out:
# [['evidence(e_ksea("ABL1", "PD153035", inc)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).'],
#  ['evidence(e_ksea("HIPK2", "PD153035", dec)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(e_ksea("HIPK2", "PD153035", dec)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(e_ksea("ABL1", "PD153035", inc)).',
#   'evidence(e_ksea("PTK2", "PD153035", dec)).',
#   'evidence(e_ksea("PTPRG", "PD153035", dec)).',
#   'evidence(e_ksea("FYN", "PD153035", dec)).',
#   'evidence(e_ksea("PTK6", "PD153035", dec)).'],
#  ['evidence(e_ksea("SRC", "PD153035", inc)).',
#   'evidence(e_ksea("PTPRR", "PD153035", inc)).'],
#  ['evidence(e_ksea("ABL1", "PD153035", inc)).'],
#  ['evidence(e_ksea("ABL1", "Tofacitinib", inc)).']]

# %%
inference_output = 'models/ebdt_data/sub_network/p_model/inference_log_8.txt'
inf_data_dict = inf.infer_marginf(model_inference, queries, inference_output, evidence=evidence_list)
pickle.dump(inf_data_dict, open('models/ebdt_data/sub_network/p_model/testing_releev_exp8_5i.pkl', 'wb'))
# Out:
# ['query(p_occupancy("ABI1(Y213)", "PD153035", _)).']
# 1/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0230s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0236s
# [INFO] Total time: 2.1966s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "PD153035", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).']
# 2/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0159s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0172s
# [INFO] Total time: 2.1855s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "PD153035", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "PD153035", _)).']
# 3/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0178s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0206s
# [INFO] Total time: 2.1121s
# Finished inference (['query(p_occupancy("ATF1(S198)", "PD153035", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).']
# 4/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0241s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0219s
# [INFO] Total time: 2.5183s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "PD153035", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "PD153035", _)).']
# 5/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0283s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0285s
# [INFO] Total time: 2.2285s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "PD153035", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).']
# 6/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0192s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0176s
# [INFO] Total time: 2.0607s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "PD153035", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "PD153035", _)).']
# 7/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0577s
# [INFO] Cycle breaking: 0.0050s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 1.3559s
# [INFO] Total time: 4.9169s
# Finished inference (['query(p_occupancy("PXN(Y118)", "PD153035", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "PD153035", _)).']
# 8/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0274s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0269s
# [INFO] Total time: 2.1393s
# Finished inference (['query(p_occupancy("PXN(Y88)", "PD153035", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "PD153035", _)).']
# 9/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0228s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0203s
# [INFO] Total time: 2.2932s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "PD153035", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).']
# 10/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0198s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.1069s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Tofacitinib", _)).']
# 11/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0175s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0170s
# [INFO] Total time: 2.2194s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Tofacitinib", _)).']
# 12/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0212s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0207s
# [INFO] Total time: 2.1049s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Tofacitinib", _)).']
# 13/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0165s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0203s
# [INFO] Total time: 2.1707s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Tofacitinib", _)).']
# 14/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0262s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0245s
# [INFO] Total time: 2.3044s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Tofacitinib", _)).']
# 15/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0171s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0180s
# [INFO] Total time: 2.0900s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Tofacitinib", _)).']
# 16/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0596s
# [INFO] Cycle breaking: 0.0058s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.3390s
# [INFO] Total time: 4.7366s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Tofacitinib", _)).']
# 17/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0242s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0271s
# [INFO] Total time: 2.0022s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Tofacitinib", _)).']
# 18/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0172s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0185s
# [INFO] Total time: 2.2465s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Tofacitinib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "PIK294", _)).']
# 19/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0222s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0182s
# [INFO] Total time: 2.2164s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "PIK294", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "PIK294", _)).']
# 20/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0191s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0186s
# [INFO] Total time: 2.1525s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "PIK294", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "PIK294", _)).']
# 21/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0158s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0188s
# [INFO] Total time: 2.0282s
# Finished inference (['query(p_occupancy("ATF1(S198)", "PIK294", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "PIK294", _)).']
# 22/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0181s
# [INFO] Total time: 2.4592s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "PIK294", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "PIK294", _)).']
# 23/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0269s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0261s
# [INFO] Total time: 2.4596s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "PIK294", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "PIK294", _)).']
# 24/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0230s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0236s
# [INFO] Total time: 2.1354s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "PIK294", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "PIK294", _)).']
# 25/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0628s
# [INFO] Cycle breaking: 0.0048s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.3572s
# [INFO] Total time: 4.7788s
# Finished inference (['query(p_occupancy("PXN(Y118)", "PIK294", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "PIK294", _)).']
# 26/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0279s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0271s
# [INFO] Total time: 2.0746s
# Finished inference (['query(p_occupancy("PXN(Y88)", "PIK294", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "PIK294", _)).']
# 27/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0206s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0182s
# [INFO] Total time: 2.1572s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "PIK294", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Ulixertinib", _)).']
# 28/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0253s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0203s
# [INFO] Total time: 2.1965s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Ulixertinib", _)).']
# 29/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0189s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0190s
# [INFO] Total time: 2.4240s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Ulixertinib", _)).']
# 30/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0174s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0209s
# [INFO] Total time: 2.0963s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Ulixertinib", _)).']
# 31/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0174s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0177s
# [INFO] Total time: 2.2862s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Ulixertinib", _)).']
# 32/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0316s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0271s
# [INFO] Total time: 2.4442s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Ulixertinib", _)).']
# 33/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0167s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0182s
# [INFO] Total time: 2.2319s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Ulixertinib", _)).']
# 34/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0002s
# [INFO] Grounding: 0.0657s
# [INFO] Cycle breaking: 0.0066s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 1.4207s
# [INFO] Total time: 5.0365s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Ulixertinib", _)).']
# 35/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0272s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0253s
# [INFO] Total time: 2.2465s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Ulixertinib", _)).']
# 36/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0192s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0226s
# [INFO] Total time: 2.2377s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Ulixertinib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "GSK690693", _)).']
# 37/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0155s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0190s
# [INFO] Total time: 2.3504s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "GSK690693", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "GSK690693", _)).']
# 38/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0175s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0212s
# [INFO] Total time: 1.9916s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "GSK690693", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "GSK690693", _)).']
# 39/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0249s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0187s
# [INFO] Total time: 2.2508s
# Finished inference (['query(p_occupancy("ATF1(S198)", "GSK690693", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "GSK690693", _)).']
# 40/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0180s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0181s
# [INFO] Total time: 2.1069s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "GSK690693", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "GSK690693", _)).']
# 41/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0231s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0274s
# [INFO] Total time: 2.0843s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "GSK690693", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "GSK690693", _)).']
# 42/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0164s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0214s
# [INFO] Total time: 2.0487s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "GSK690693", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "GSK690693", _)).']
# 43/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0661s
# [INFO] Cycle breaking: 0.0045s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.4629s
# [INFO] Total time: 5.2961s
# Finished inference (['query(p_occupancy("PXN(Y118)", "GSK690693", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "GSK690693", _)).']
# 44/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0288s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0324s
# [INFO] Total time: 2.8826s
# Finished inference (['query(p_occupancy("PXN(Y88)", "GSK690693", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "GSK690693", _)).']
# 45/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0268s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0270s
# [INFO] Total time: 2.7273s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "GSK690693", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "KN62", _)).']
# 46/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0160s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0227s
# [INFO] Total time: 2.2920s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "KN62", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "KN62", _)).']
# 47/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0228s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0209s
# [INFO] Total time: 2.3979s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "KN62", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "KN62", _)).']
# 48/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0290s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0212s
# [INFO] Total time: 2.7457s
# Finished inference (['query(p_occupancy("ATF1(S198)", "KN62", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "KN62", _)).']
# 49/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0203s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0199s
# [INFO] Total time: 2.4111s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "KN62", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "KN62", _)).']
# 50/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0276s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0302s
# [INFO] Total time: 2.3818s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "KN62", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "KN62", _)).']
# 51/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0180s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0197s
# [INFO] Total time: 2.1639s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "KN62", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "KN62", _)).']
# 52/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0594s
# [INFO] Cycle breaking: 0.0053s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 1.3473s
# [INFO] Total time: 4.8467s
# Finished inference (['query(p_occupancy("PXN(Y118)", "KN62", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "KN62", _)).']
# 53/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0258s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0251s
# [INFO] Total time: 2.2437s
# Finished inference (['query(p_occupancy("PXN(Y88)", "KN62", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "KN62", _)).']
# 54/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0150s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0166s
# [INFO] Total time: 2.0425s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "KN62", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "PF4708671", _)).']
# 55/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0173s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0217s
# [INFO] Total time: 2.1257s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "PF4708671", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "PF4708671", _)).']
# 56/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0233s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0181s
# [INFO] Total time: 2.0480s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "PF4708671", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "PF4708671", _)).']
# 57/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0157s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0175s
# [INFO] Total time: 2.1556s
# Finished inference (['query(p_occupancy("ATF1(S198)", "PF4708671", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "PF4708671", _)).']
# 58/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0163s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0218s
# [INFO] Total time: 2.0204s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "PF4708671", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "PF4708671", _)).']
# 59/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0281s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0287s
# [INFO] Total time: 2.1697s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "PF4708671", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "PF4708671", _)).']
# 60/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0225s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0232s
# [INFO] Total time: 2.3581s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "PF4708671", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "PF4708671", _)).']
# 61/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0582s
# [INFO] Cycle breaking: 0.0044s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.3669s
# [INFO] Total time: 4.7687s
# Finished inference (['query(p_occupancy("PXN(Y118)", "PF4708671", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "PF4708671", _)).']
# 62/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0267s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0258s
# [INFO] Total time: 2.1994s
# Finished inference (['query(p_occupancy("PXN(Y88)", "PF4708671", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "PF4708671", _)).']
# 63/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0189s
# [INFO] Total time: 2.0613s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "PF4708671", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "AZD6738", _)).']
# 64/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0174s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0171s
# [INFO] Total time: 1.9325s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "AZD6738", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "AZD6738", _)).']
# 65/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0157s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0161s
# [INFO] Total time: 2.0578s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "AZD6738", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "AZD6738", _)).']
# 66/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0164s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0207s
# [INFO] Total time: 2.2323s
# Finished inference (['query(p_occupancy("ATF1(S198)", "AZD6738", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "AZD6738", _)).']
# 67/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0186s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0177s
# [INFO] Total time: 1.9610s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "AZD6738", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "AZD6738", _)).']
# 68/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0253s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0253s
# [INFO] Total time: 2.0374s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "AZD6738", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "AZD6738", _)).']
# 69/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0180s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0205s
# [INFO] Total time: 2.0481s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "AZD6738", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "AZD6738", _)).']
# 70/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0668s
# [INFO] Cycle breaking: 0.0047s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 1.3230s
# [INFO] Total time: 4.6766s
# Finished inference (['query(p_occupancy("PXN(Y118)", "AZD6738", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "AZD6738", _)).']
# 71/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0300s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0271s
# [INFO] Total time: 2.1146s
# Finished inference (['query(p_occupancy("PXN(Y88)", "AZD6738", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "AZD6738", _)).']
# 72/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0191s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0192s
# [INFO] Total time: 2.2635s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "AZD6738", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Dasatinib", _)).']
# 73/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0163s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0172s
# [INFO] Total time: 2.2228s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Dasatinib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Dasatinib", _)).']
# 74/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0154s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0180s
# [INFO] Total time: 2.0434s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Dasatinib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Dasatinib", _)).']
# 75/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0203s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0196s
# [INFO] Total time: 2.1215s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Dasatinib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Dasatinib", _)).']
# 76/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0191s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0178s
# [INFO] Total time: 2.1757s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Dasatinib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Dasatinib", _)).']
# 77/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0257s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0272s
# [INFO] Total time: 2.1859s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Dasatinib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Dasatinib", _)).']
# 78/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0187s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0167s
# [INFO] Total time: 2.0334s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Dasatinib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Dasatinib", _)).']
# 79/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0665s
# [INFO] Cycle breaking: 0.0058s
# [INFO] Clark's completion: 0.0007s
# [INFO] DSharp compilation: 1.2723s
# [INFO] Total time: 4.4410s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Dasatinib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Dasatinib", _)).']
# 80/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0281s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0264s
# [INFO] Total time: 2.0639s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Dasatinib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Dasatinib", _)).']
# 81/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0204s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0191s
# [INFO] Total time: 2.1640s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Dasatinib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "KD025", _)).']
# 82/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0172s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0189s
# [INFO] Total time: 2.2487s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "KD025", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "KD025", _)).']
# 83/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0193s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0195s
# [INFO] Total time: 1.9879s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "KD025", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "KD025", _)).']
# 84/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# ...
# 90/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0177s
# [INFO] Total time: 2.0182s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "KD025", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "Vemurafenib", _)).']
# 91/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0152s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0201s
# [INFO] Total time: 2.0911s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "Vemurafenib", _)).']
# 92/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0159s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0197s
# [INFO] Total time: 2.0360s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "Vemurafenib", _)).']
# 93/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0184s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0190s
# [INFO] Total time: 2.0370s
# Finished inference (['query(p_occupancy("ATF1(S198)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "Vemurafenib", _)).']
# 94/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0164s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0230s
# [INFO] Total time: 2.1900s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "Vemurafenib", _)).']
# 95/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0218s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0263s
# [INFO] Total time: 2.0520s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "Vemurafenib", _)).']
# 96/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0161s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0197s
# [INFO] Total time: 2.2026s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "Vemurafenib", _)).']
# 97/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0590s
# [INFO] Cycle breaking: 0.0047s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 1.3082s
# [INFO] Total time: 4.3965s
# Finished inference (['query(p_occupancy("PXN(Y118)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "Vemurafenib", _)).']
# 98/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0223s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0237s
# [INFO] Total time: 1.9398s
# Finished inference (['query(p_occupancy("PXN(Y88)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "Vemurafenib", _)).']
# 99/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0158s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0171s
# [INFO] Total time: 2.0284s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "Vemurafenib", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "GO6983", _)).']
# 100/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0162s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0169s
# [INFO] Total time: 2.0336s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "GO6983", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "GO6983", _)).']
# 101/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0153s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0175s
# [INFO] Total time: 2.0695s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "GO6983", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "GO6983", _)).']
# 102/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0158s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0183s
# [INFO] Total time: 2.0175s
# Finished inference (['query(p_occupancy("ATF1(S198)", "GO6983", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "GO6983", _)).']
# 103/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0163s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0181s
# [INFO] Total time: 2.2187s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "GO6983", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "GO6983", _)).']
# 104/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0245s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0230s
# [INFO] Total time: 2.0569s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "GO6983", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "GO6983", _)).']
# 105/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0161s
# [INFO] Cycle breaking: 0.0014s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0174s
# [INFO] Total time: 2.0498s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "GO6983", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "GO6983", _)).']
# 106/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0525s
# [INFO] Cycle breaking: 0.0045s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 1.2827s
# [INFO] Total time: 4.4604s
# Finished inference (['query(p_occupancy("PXN(Y118)", "GO6983", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "GO6983", _)).']
# 107/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0307s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0258s
# [INFO] Total time: 2.0985s
# Finished inference (['query(p_occupancy("PXN(Y88)", "GO6983", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "GO6983", _)).']
# 108/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0155s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0176s
# [INFO] Total time: 1.8942s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "GO6983", _)).'])...
# ['query(p_occupancy("ABI1(Y213)", "MK2206", _)).']
# 109/117
# Inferring data (['query(p_occupancy("ABI1(Y213)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0225s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0338s
# [INFO] Total time: 1.9633s
# Finished inference (['query(p_occupancy("ABI1(Y213)", "MK2206", _)).'])...
# ['query(p_occupancy("ANXA2P2(Y24)", "MK2206", _)).']
# 110/117
# Inferring data (['query(p_occupancy("ANXA2P2(Y24)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0184s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0240s
# [INFO] Total time: 2.1497s
# Finished inference (['query(p_occupancy("ANXA2P2(Y24)", "MK2206", _)).'])...
# ['query(p_occupancy("ATF1(S198)", "MK2206", _)).']
# 111/117
# Inferring data (['query(p_occupancy("ATF1(S198)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0159s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0186s
# [INFO] Total time: 2.1774s
# Finished inference (['query(p_occupancy("ATF1(S198)", "MK2206", _)).'])...
# ['query(p_occupancy("BCLAF1(Y284)", "MK2206", _)).']
# 112/117
# Inferring data (['query(p_occupancy("BCLAF1(Y284)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0253s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0173s
# [INFO] Total time: 2.1162s
# Finished inference (['query(p_occupancy("BCLAF1(Y284)", "MK2206", _)).'])...
# ['query(p_occupancy("HIPK2(Y361)", "MK2206", _)).']
# 113/117
# Inferring data (['query(p_occupancy("HIPK2(Y361)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0289s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0303s
# [INFO] Total time: 2.1838s
# Finished inference (['query(p_occupancy("HIPK2(Y361)", "MK2206", _)).'])...
# ['query(p_occupancy("PTTG1IP(Y174)", "MK2206", _)).']
# 114/117
# Inferring data (['query(p_occupancy("PTTG1IP(Y174)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0190s
# [INFO] Cycle breaking: 0.0013s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0192s
# [INFO] Total time: 2.0900s
# Finished inference (['query(p_occupancy("PTTG1IP(Y174)", "MK2206", _)).'])...
# ['query(p_occupancy("PXN(Y118)", "MK2206", _)).']
# 115/117
# Inferring data (['query(p_occupancy("PXN(Y118)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0002s
# [INFO] Grounding: 0.0529s
# [INFO] Cycle breaking: 0.0041s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 1.3047s
# [INFO] Total time: 4.5189s
# Finished inference (['query(p_occupancy("PXN(Y118)", "MK2206", _)).'])...
# ['query(p_occupancy("PXN(Y88)", "MK2206", _)).']
# 116/117
# Inferring data (['query(p_occupancy("PXN(Y88)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0305s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0278s
# [INFO] Total time: 2.4248s
# Finished inference (['query(p_occupancy("PXN(Y88)", "MK2206", _)).'])...
# ['query(p_occupancy("RBM39(Y95)", "MK2206", _)).']
# 117/117
# Inferring data (['query(p_occupancy("RBM39(Y95)", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/p_model/p_model_exp8_testing_5i.pl -o models/ebdt_data/sub_network/p_model/inference_log_8.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0180s
# [INFO] Total time: 2.3501s
# Finished inference (['query(p_occupancy("RBM39(Y95)", "MK2206", _)).'])...
