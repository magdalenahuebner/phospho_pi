# %% [markdown]
# #### Prerequesites:
# * Define schema (make figure)
# * Define structure (make figure)
# * Define schema class in python (src/models/model_schemata.py)
# * Convert schema + structure into model template (models/templates/p_model.pl)
#
# #### Procedure:
# * Load data
# * Adjust model script for lfi accordingly
# * Create evidence file (if I don't need different evidence files, move to builmodel notebook)
# * LFI

# %% [markdown]
# Multiple instances, 1 pst, X enzymes, one sample per instance, multiple enzymes per instance, test how many enzymes can have in one instances, how computing time depends on N p::f for 60 samples

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os
import pickle
import random

from src.models import model_schemata as schema
from src.models import build_model as build
from src.models import parameter_learning as lfi
from src.models import inference as inf
from src.visualization import visualize as viz

# %%
os.chdir('/Users/magdalena/OneDrive - Queen Mary, University of London/bezzlab/research/projects/phospho_pi/')
# os.chdir('/home/mhuebner/Desktop/bezzlab/research/projects/phospho_pi/')

# %% [markdown]
# #### Inference (I)

# %%
# reading csv from files into dict
data = {}
data['e_ksea'] = pd.read_csv('data/processed/ebdt_data/sub_network_e/e_ksea.csv')
data['p_fc'] = pd.read_csv('data/processed/ebdt_data/sub_network_e/p_fc.csv')

# %%
# getting sample names (union of all samples in all datasets)
samples = list(set(data['e_ksea']['sample']).union(set(data['p_fc']['sample'])))
samples.sort()
# sample x% of samples randomly without replacement with seed
random.seed(612)
train = random.sample(samples, int(len(samples)*0.8))
test = [x for x in samples if x not in train]
print(test)
# filter data
testing_data = {}
testing_data['e_ksea'] = data['e_ksea'][data['e_ksea']['sample'].isin(test)].reset_index(drop=True)
testing_data['p_fc'] = data['p_fc'][data['p_fc']['sample'].isin(test)].reset_index(drop=True)
# Out:
# ['AZD6738', 'Dasatinib', 'GO6983', 'GSK690693', 'KD025', 'KN62', 'MK2206', 'PD153035', 'PF4708671', 'PIK294', 'Tofacitinib', 'Ulixertinib', 'Vemurafenib']

# %%
# Adding evidence
model_inference = 'models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl'

# %% [markdown]
# #### Inferring p_occupancy

# %% [markdown]
# Adding queries

# %%
sample_ids = testing_data['e_ksea']['sample'].unique().tolist()
enzymes = testing_data['e_ksea']['enzyme'].unique().tolist()
queries = inf.generate_queries(schema.EActivityPredicate, sample_ids=sample_ids, enzymes=enzymes)
len(queries)
# Out:
# 78

# %%
queries[:10]
# Out:
# ['query(e_activity("ABL1", "AZD6738", _)).',
#  'query(e_activity("FYN", "AZD6738", _)).',
#  'query(e_activity("HIPK2", "AZD6738", _)).',
#  'query(e_activity("PTK2", "AZD6738", _)).',
#  'query(e_activity("PTPRG", "AZD6738", _)).',
#  'query(e_activity("SRC", "AZD6738", _)).',
#  'query(e_activity("ABL1", "Dasatinib", _)).',
#  'query(e_activity("FYN", "Dasatinib", _)).',
#  'query(e_activity("HIPK2", "Dasatinib", _)).',
#  'query(e_activity("PTK2", "Dasatinib", _)).']

# %% [markdown]
# Adding evidence (phosphosite and relevant enzymes)

# %%
data['p_regulates'] = pd.read_csv('data/processed/ebdt_data/sub_network_e/p_regulates.csv')

# %%
# Mapping data to Problog predicates
predicates = {}
predicates['p_fc'] = schema.PFoldChangePredicate()
predicates['p_fc'].add_data(testing_data['p_fc'], 'phosphosite', 'sample', 'value')
predicates['e_ksea'] = schema.EKseaPredicate()
predicates['e_ksea'].add_data(testing_data['e_ksea'], 'enzyme', 'sample', 'value')

# %%
evidence_dict = {}
for s in sample_ids:
    evidence_dict[s] = {}
    for e in enzymes:
        phosphosites = data['p_regulates']['phosphosite'][data['p_regulates']['protein'] == e].tolist()
        evid_generator = build.ProblogStatementGenerator(predicates['p_fc'])
        evidence_p = []
        for p in phosphosites:
            evidence_p.extend(evid_generator.generate_facts(build.EvidenceTemplate, select=[s, p]))
        evid_generator = build.ProblogStatementGenerator(predicates['e_ksea'])
        evidence_e = evid_generator.generate_facts(build.EvidenceTemplate, select=[s, e])
        evidence_dict[s][e] = evidence_p + evidence_e

# %%
# make evidence_dict['AZD5438'] into list
evidence_list = []
for s in evidence_dict.keys():
    for e in evidence_dict[s]:
        evidence_list.append(evidence_dict[s][e])
evidence_list[:10]
# Out:
# [['evidence(p_fc("ABL1(S569)", "AZD6738", dec)).',
#   'evidence(p_fc("ABL1(S718)", "AZD6738", dec)).',
#   'evidence(p_fc("ABL1(T735)", "AZD6738", inc)).',
#   'evidence(e_ksea("ABL1", "AZD6738", dec)).'],
#  ['evidence(e_ksea("FYN", "AZD6738", inc)).'],
#  ['evidence(p_fc("HIPK2(Y361)", "AZD6738", dec)).',
#   'evidence(e_ksea("HIPK2", "AZD6738", inc)).'],
#  ['evidence(p_fc("PTK2(S29)", "AZD6738", inc)).',
#   'evidence(p_fc("PTK2(S722)", "AZD6738", dec)).',
#   'evidence(p_fc("PTK2(S910)", "AZD6738", dec)).',
#   'evidence(p_fc("PTK2(S843)", "AZD6738", inc)).',
#   'evidence(e_ksea("PTK2", "AZD6738", inc)).'],
#  ['evidence(p_fc("PTPRG(S995)", "AZD6738", dec)).',
#   'evidence(e_ksea("PTPRG", "AZD6738", inc)).'],
#  ['evidence(p_fc("SRC(S17)", "AZD6738", dec)).',
#   'evidence(p_fc("SRC(S75)", "AZD6738", inc)).',
#   'evidence(e_ksea("SRC", "AZD6738", dec)).'],
#  ['evidence(p_fc("ABL1(S569)", "Dasatinib", dec)).',
#   'evidence(p_fc("ABL1(S718)", "Dasatinib", dec)).',
#   'evidence(p_fc("ABL1(T735)", "Dasatinib", inc)).',
#   'evidence(e_ksea("ABL1", "Dasatinib", dec)).'],
#  ['evidence(e_ksea("FYN", "Dasatinib", inc)).'],
#  ['evidence(p_fc("HIPK2(Y361)", "Dasatinib", inc)).',
#   'evidence(e_ksea("HIPK2", "Dasatinib", inc)).'],
#  ['evidence(p_fc("PTK2(S29)", "Dasatinib", dec)).',
#   'evidence(p_fc("PTK2(S722)", "Dasatinib", dec)).',
#   'evidence(p_fc("PTK2(S910)", "Dasatinib", inc)).',
#   'evidence(p_fc("PTK2(S843)", "Dasatinib", dec)).',
#   'evidence(e_ksea("PTK2", "Dasatinib", inc)).']]

# %%
inference_output = 'models/ebdt_data/sub_network/e_model/inference_log_2.txt'
inf_data_dict = inf.infer_marginf(model_inference, queries, inference_output, evidence=evidence_list)
pickle.dump(inf_data_dict, open('models/ebdt_data/sub_network/e_model/testing_exp2_100i.pkl', 'wb'))
# Out:
# ['query(e_activity("ABL1", "AZD6738", _)).']
# 1/78
# Inferring data (['query(e_activity("ABL1", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0328s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0390s
# [INFO] Total time: 1.7942s
# Finished inference (['query(e_activity("ABL1", "AZD6738", _)).'])...
# ['query(e_activity("FYN", "AZD6738", _)).']
# 2/78
# Inferring data (['query(e_activity("FYN", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0080s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0136s
# [INFO] Total time: 1.5535s
# Finished inference (['query(e_activity("FYN", "AZD6738", _)).'])...
# ['query(e_activity("HIPK2", "AZD6738", _)).']
# 3/78
# Inferring data (['query(e_activity("HIPK2", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0172s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0139s
# [INFO] Total time: 1.5583s
# Finished inference (['query(e_activity("HIPK2", "AZD6738", _)).'])...
# ['query(e_activity("PTK2", "AZD6738", _)).']
# 4/78
# Inferring data (['query(e_activity("PTK2", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0397s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0884s
# [INFO] Total time: 1.7144s
# Finished inference (['query(e_activity("PTK2", "AZD6738", _)).'])...
# ['query(e_activity("PTPRG", "AZD6738", _)).']
# 5/78
# Inferring data (['query(e_activity("PTPRG", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0197s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0170s
# [INFO] Total time: 1.5604s
# Finished inference (['query(e_activity("PTPRG", "AZD6738", _)).'])...
# ['query(e_activity("SRC", "AZD6738", _)).']
# 6/78
# Inferring data (['query(e_activity("SRC", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0220s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0178s
# [INFO] Total time: 1.5566s
# Finished inference (['query(e_activity("SRC", "AZD6738", _)).'])...
# ['query(e_activity("ABL1", "Dasatinib", _)).']
# 7/78
# Inferring data (['query(e_activity("ABL1", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0315s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0434s
# [INFO] Total time: 1.6330s
# Finished inference (['query(e_activity("ABL1", "Dasatinib", _)).'])...
# ['query(e_activity("FYN", "Dasatinib", _)).']
# 8/78
# Inferring data (['query(e_activity("FYN", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0121s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0135s
# [INFO] Total time: 1.5681s
# Finished inference (['query(e_activity("FYN", "Dasatinib", _)).'])...
# ['query(e_activity("HIPK2", "Dasatinib", _)).']
# 9/78
# Inferring data (['query(e_activity("HIPK2", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0187s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0202s
# [INFO] Total time: 1.6687s
# Finished inference (['query(e_activity("HIPK2", "Dasatinib", _)).'])...
# ['query(e_activity("PTK2", "Dasatinib", _)).']
# 10/78
# Inferring data (['query(e_activity("PTK2", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0390s
# [INFO] Cycle breaking: 0.0038s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0885s
# [INFO] Total time: 1.7730s
# Finished inference (['query(e_activity("PTK2", "Dasatinib", _)).'])...
# ['query(e_activity("PTPRG", "Dasatinib", _)).']
# 11/78
# Inferring data (['query(e_activity("PTPRG", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0198s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0172s
# [INFO] Total time: 1.5811s
# Finished inference (['query(e_activity("PTPRG", "Dasatinib", _)).'])...
# ['query(e_activity("SRC", "Dasatinib", _)).']
# 12/78
# Inferring data (['query(e_activity("SRC", "Dasatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0230s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0179s
# [INFO] Total time: 1.5915s
# Finished inference (['query(e_activity("SRC", "Dasatinib", _)).'])...
# ['query(e_activity("ABL1", "GO6983", _)).']
# 13/78
# Inferring data (['query(e_activity("ABL1", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0323s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0319s
# [INFO] Total time: 1.6402s
# Finished inference (['query(e_activity("ABL1", "GO6983", _)).'])...
# ['query(e_activity("FYN", "GO6983", _)).']
# 14/78
# Inferring data (['query(e_activity("FYN", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0075s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0118s
# [INFO] Total time: 1.5830s
# Finished inference (['query(e_activity("FYN", "GO6983", _)).'])...
# ['query(e_activity("HIPK2", "GO6983", _)).']
# 15/78
# Inferring data (['query(e_activity("HIPK2", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0166s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0146s
# [INFO] Total time: 1.6033s
# Finished inference (['query(e_activity("HIPK2", "GO6983", _)).'])...
# ['query(e_activity("PTK2", "GO6983", _)).']
# 16/78
# Inferring data (['query(e_activity("PTK2", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0394s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0940s
# [INFO] Total time: 1.8420s
# Finished inference (['query(e_activity("PTK2", "GO6983", _)).'])...
# ['query(e_activity("PTPRG", "GO6983", _)).']
# 17/78
# Inferring data (['query(e_activity("PTPRG", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0219s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0168s
# [INFO] Total time: 1.6780s
# Finished inference (['query(e_activity("PTPRG", "GO6983", _)).'])...
# ['query(e_activity("SRC", "GO6983", _)).']
# 18/78
# Inferring data (['query(e_activity("SRC", "GO6983", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0221s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0245s
# [INFO] Total time: 1.5994s
# Finished inference (['query(e_activity("SRC", "GO6983", _)).'])...
# ['query(e_activity("ABL1", "GSK690693", _)).']
# 19/78
# Inferring data (['query(e_activity("ABL1", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0421s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0430s
# [INFO] Total time: 3.2544s
# Finished inference (['query(e_activity("ABL1", "GSK690693", _)).'])...
# ['query(e_activity("FYN", "GSK690693", _)).']
# 20/78
# Inferring data (['query(e_activity("FYN", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0096s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0135s
# [INFO] Total time: 1.9663s
# Finished inference (['query(e_activity("FYN", "GSK690693", _)).'])...
# ['query(e_activity("HIPK2", "GSK690693", _)).']
# 21/78
# Inferring data (['query(e_activity("HIPK2", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0180s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0153s
# [INFO] Total time: 1.6743s
# Finished inference (['query(e_activity("HIPK2", "GSK690693", _)).'])...
# ['query(e_activity("PTK2", "GSK690693", _)).']
# 22/78
# Inferring data (['query(e_activity("PTK2", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0411s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0864s
# [INFO] Total time: 1.8463s
# Finished inference (['query(e_activity("PTK2", "GSK690693", _)).'])...
# ['query(e_activity("PTPRG", "GSK690693", _)).']
# 23/78
# Inferring data (['query(e_activity("PTPRG", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0196s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0293s
# [INFO] Total time: 2.2577s
# Finished inference (['query(e_activity("PTPRG", "GSK690693", _)).'])...
# ['query(e_activity("SRC", "GSK690693", _)).']
# 24/78
# Inferring data (['query(e_activity("SRC", "GSK690693", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0253s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0186s
# [INFO] Total time: 1.6431s
# Finished inference (['query(e_activity("SRC", "GSK690693", _)).'])...
# ['query(e_activity("ABL1", "KD025", _)).']
# 25/78
# Inferring data (['query(e_activity("ABL1", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0375s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0351s
# [INFO] Total time: 1.6961s
# Finished inference (['query(e_activity("ABL1", "KD025", _)).'])...
# ['query(e_activity("FYN", "KD025", _)).']
# 26/78
# Inferring data (['query(e_activity("FYN", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0098s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0151s
# [INFO] Total time: 2.6146s
# Finished inference (['query(e_activity("FYN", "KD025", _)).'])...
# ['query(e_activity("HIPK2", "KD025", _)).']
# 27/78
# Inferring data (['query(e_activity("HIPK2", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0220s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0231s
# [INFO] Total time: 2.0215s
# Finished inference (['query(e_activity("HIPK2", "KD025", _)).'])...
# ['query(e_activity("PTK2", "KD025", _)).']
# 28/78
# Inferring data (['query(e_activity("PTK2", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0474s
# [INFO] Cycle breaking: 0.0041s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1238s
# [INFO] Total time: 2.5830s
# Finished inference (['query(e_activity("PTK2", "KD025", _)).'])...
# ['query(e_activity("PTPRG", "KD025", _)).']
# 29/78
# Inferring data (['query(e_activity("PTPRG", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0393s
# [INFO] Cycle breaking: 0.0088s
# [INFO] Clark's completion: 0.0006s
# [INFO] DSharp compilation: 0.0233s
# [INFO] Total time: 1.8432s
# Finished inference (['query(e_activity("PTPRG", "KD025", _)).'])...
# ['query(e_activity("SRC", "KD025", _)).']
# 30/78
# Inferring data (['query(e_activity("SRC", "KD025", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0231s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0182s
# [INFO] Total time: 1.7087s
# Finished inference (['query(e_activity("SRC", "KD025", _)).'])...
# ['query(e_activity("ABL1", "KN62", _)).']
# 31/78
# Inferring data (['query(e_activity("ABL1", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0421s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.0501s
# [INFO] Total time: 1.7568s
# Finished inference (['query(e_activity("ABL1", "KN62", _)).'])...
# ['query(e_activity("FYN", "KN62", _)).']
# 32/78
# Inferring data (['query(e_activity("FYN", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0090s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0177s
# [INFO] Total time: 2.1388s
# Finished inference (['query(e_activity("FYN", "KN62", _)).'])...
# ['query(e_activity("HIPK2", "KN62", _)).']
# 33/78
# Inferring data (['query(e_activity("HIPK2", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0201s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0239s
# [INFO] Total time: 1.9050s
# Finished inference (['query(e_activity("HIPK2", "KN62", _)).'])...
# ['query(e_activity("PTK2", "KN62", _)).']
# 34/78
# Inferring data (['query(e_activity("PTK2", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0391s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0952s
# [INFO] Total time: 1.8592s
# Finished inference (['query(e_activity("PTK2", "KN62", _)).'])...
# ['query(e_activity("PTPRG", "KN62", _)).']
# 35/78
# Inferring data (['query(e_activity("PTPRG", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0190s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0169s
# [INFO] Total time: 1.6581s
# Finished inference (['query(e_activity("PTPRG", "KN62", _)).'])...
# ['query(e_activity("SRC", "KN62", _)).']
# 36/78
# Inferring data (['query(e_activity("SRC", "KN62", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0239s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0179s
# [INFO] Total time: 1.6585s
# Finished inference (['query(e_activity("SRC", "KN62", _)).'])...
# ['query(e_activity("ABL1", "MK2206", _)).']
# 37/78
# Inferring data (['query(e_activity("ABL1", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0300s
# [INFO] Cycle breaking: 0.0030s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0429s
# [INFO] Total time: 1.6425s
# Finished inference (['query(e_activity("ABL1", "MK2206", _)).'])...
# ['query(e_activity("FYN", "MK2206", _)).']
# 38/78
# Inferring data (['query(e_activity("FYN", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0081s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0121s
# [INFO] Total time: 1.5803s
# Finished inference (['query(e_activity("FYN", "MK2206", _)).'])...
# ['query(e_activity("HIPK2", "MK2206", _)).']
# 39/78
# Inferring data (['query(e_activity("HIPK2", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0167s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0146s
# [INFO] Total time: 1.5811s
# Finished inference (['query(e_activity("HIPK2", "MK2206", _)).'])...
# ['query(e_activity("PTK2", "MK2206", _)).']
# 40/78
# Inferring data (['query(e_activity("PTK2", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0774s
# [INFO] Cycle breaking: 0.0047s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1077s
# [INFO] Total time: 2.2637s
# Finished inference (['query(e_activity("PTK2", "MK2206", _)).'])...
# ['query(e_activity("PTPRG", "MK2206", _)).']
# 41/78
# Inferring data (['query(e_activity("PTPRG", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0254s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0210s
# [INFO] Total time: 2.5431s
# Finished inference (['query(e_activity("PTPRG", "MK2206", _)).'])...
# ['query(e_activity("SRC", "MK2206", _)).']
# 42/78
# Inferring data (['query(e_activity("SRC", "MK2206", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0282s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0397s
# [INFO] Total time: 1.8915s
# Finished inference (['query(e_activity("SRC", "MK2206", _)).'])...
# ['query(e_activity("ABL1", "PD153035", _)).']
# 43/78
# Inferring data (['query(e_activity("ABL1", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0341s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0435s
# [INFO] Total time: 1.9279s
# Finished inference (['query(e_activity("ABL1", "PD153035", _)).'])...
# ['query(e_activity("FYN", "PD153035", _)).']
# 44/78
# Inferring data (['query(e_activity("FYN", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0088s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0106s
# [INFO] Total time: 1.8483s
# Finished inference (['query(e_activity("FYN", "PD153035", _)).'])...
# ['query(e_activity("HIPK2", "PD153035", _)).']
# 45/78
# Inferring data (['query(e_activity("HIPK2", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0186s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0178s
# [INFO] Total time: 1.7676s
# Finished inference (['query(e_activity("HIPK2", "PD153035", _)).'])...
# ['query(e_activity("PTK2", "PD153035", _)).']
# 46/78
# Inferring data (['query(e_activity("PTK2", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0393s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1006s
# [INFO] Total time: 1.7693s
# Finished inference (['query(e_activity("PTK2", "PD153035", _)).'])...
# ['query(e_activity("PTPRG", "PD153035", _)).']
# 47/78
# Inferring data (['query(e_activity("PTPRG", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0203s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0211s
# [INFO] Total time: 1.8240s
# Finished inference (['query(e_activity("PTPRG", "PD153035", _)).'])...
# ['query(e_activity("SRC", "PD153035", _)).']
# 48/78
# Inferring data (['query(e_activity("SRC", "PD153035", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0274s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0248s
# [INFO] Total time: 1.7772s
# Finished inference (['query(e_activity("SRC", "PD153035", _)).'])...
# ['query(e_activity("ABL1", "PF4708671", _)).']
# 49/78
# Inferring data (['query(e_activity("ABL1", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0506s
# [INFO] Cycle breaking: 0.0050s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1107s
# [INFO] Total time: 2.1453s
# Finished inference (['query(e_activity("ABL1", "PF4708671", _)).'])...
# ['query(e_activity("FYN", "PF4708671", _)).']
# 50/78
# Inferring data (['query(e_activity("FYN", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0100s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0121s
# [INFO] Total time: 2.5701s
# Finished inference (['query(e_activity("FYN", "PF4708671", _)).'])...
# ['query(e_activity("HIPK2", "PF4708671", _)).']
# 51/78
# Inferring data (['query(e_activity("HIPK2", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0189s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0142s
# [INFO] Total time: 2.0421s
# Finished inference (['query(e_activity("HIPK2", "PF4708671", _)).'])...
# ['query(e_activity("PTK2", "PF4708671", _)).']
# 52/78
# Inferring data (['query(e_activity("PTK2", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0403s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0915s
# [INFO] Total time: 1.8038s
# Finished inference (['query(e_activity("PTK2", "PF4708671", _)).'])...
# ['query(e_activity("PTPRG", "PF4708671", _)).']
# 53/78
# Inferring data (['query(e_activity("PTPRG", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0201s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0171s
# [INFO] Total time: 1.5849s
# Finished inference (['query(e_activity("PTPRG", "PF4708671", _)).'])...
# ['query(e_activity("SRC", "PF4708671", _)).']
# 54/78
# Inferring data (['query(e_activity("SRC", "PF4708671", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0271s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0187s
# [INFO] Total time: 1.9202s
# Finished inference (['query(e_activity("SRC", "PF4708671", _)).'])...
# ['query(e_activity("ABL1", "PIK294", _)).']
# 55/78
# Inferring data (['query(e_activity("ABL1", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0396s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0405s
# [INFO] Total time: 1.8444s
# Finished inference (['query(e_activity("ABL1", "PIK294", _)).'])...
# ['query(e_activity("FYN", "PIK294", _)).']
# 56/78
# Inferring data (['query(e_activity("FYN", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0080s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0101s
# [INFO] Total time: 1.6438s
# Finished inference (['query(e_activity("FYN", "PIK294", _)).'])...
# ['query(e_activity("HIPK2", "PIK294", _)).']
# 57/78
# Inferring data (['query(e_activity("HIPK2", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0168s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0137s
# [INFO] Total time: 1.6084s
# Finished inference (['query(e_activity("HIPK2", "PIK294", _)).'])...
# ['query(e_activity("PTK2", "PIK294", _)).']
# 58/78
# Inferring data (['query(e_activity("PTK2", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0375s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0963s
# [INFO] Total time: 1.7903s
# Finished inference (['query(e_activity("PTK2", "PIK294", _)).'])...
# ['query(e_activity("PTPRG", "PIK294", _)).']
# 59/78
# Inferring data (['query(e_activity("PTPRG", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0197s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0164s
# [INFO] Total time: 1.5928s
# Finished inference (['query(e_activity("PTPRG", "PIK294", _)).'])...
# ['query(e_activity("SRC", "PIK294", _)).']
# 60/78
# Inferring data (['query(e_activity("SRC", "PIK294", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0226s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0172s
# [INFO] Total time: 1.6774s
# Finished inference (['query(e_activity("SRC", "PIK294", _)).'])...
# ['query(e_activity("ABL1", "Tofacitinib", _)).']
# 61/78
# Inferring data (['query(e_activity("ABL1", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0305s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0321s
# [INFO] Total time: 1.6760s
# Finished inference (['query(e_activity("ABL1", "Tofacitinib", _)).'])...
# ['query(e_activity("FYN", "Tofacitinib", _)).']
# 62/78
# Inferring data (['query(e_activity("FYN", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0086s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0119s
# [INFO] Total time: 1.6341s
# Finished inference (['query(e_activity("FYN", "Tofacitinib", _)).'])...
# ['query(e_activity("HIPK2", "Tofacitinib", _)).']
# 63/78
# Inferring data (['query(e_activity("HIPK2", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0160s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0148s
# [INFO] Total time: 1.5991s
# Finished inference (['query(e_activity("HIPK2", "Tofacitinib", _)).'])...
# ['query(e_activity("PTK2", "Tofacitinib", _)).']
# 64/78
# Inferring data (['query(e_activity("PTK2", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0379s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0890s
# [INFO] Total time: 1.7625s
# Finished inference (['query(e_activity("PTK2", "Tofacitinib", _)).'])...
# ['query(e_activity("PTPRG", "Tofacitinib", _)).']
# 65/78
# Inferring data (['query(e_activity("PTPRG", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0194s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0169s
# [INFO] Total time: 1.7283s
# Finished inference (['query(e_activity("PTPRG", "Tofacitinib", _)).'])...
# ['query(e_activity("SRC", "Tofacitinib", _)).']
# 66/78
# Inferring data (['query(e_activity("SRC", "Tofacitinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0227s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0220s
# [INFO] Total time: 1.6206s
# Finished inference (['query(e_activity("SRC", "Tofacitinib", _)).'])...
# ['query(e_activity("ABL1", "Ulixertinib", _)).']
# 67/78
# Inferring data (['query(e_activity("ABL1", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0309s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0325s
# [INFO] Total time: 1.6618s
# Finished inference (['query(e_activity("ABL1", "Ulixertinib", _)).'])...
# ['query(e_activity("FYN", "Ulixertinib", _)).']
# 68/78
# Inferring data (['query(e_activity("FYN", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0076s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0122s
# [INFO] Total time: 1.5972s
# Finished inference (['query(e_activity("FYN", "Ulixertinib", _)).'])...
# ['query(e_activity("HIPK2", "Ulixertinib", _)).']
# 69/78
# Inferring data (['query(e_activity("HIPK2", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0022s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0161s
# [INFO] Total time: 1.5973s
# Finished inference (['query(e_activity("HIPK2", "Ulixertinib", _)).'])...
# ['query(e_activity("PTK2", "Ulixertinib", _)).']
# 70/78
# Inferring data (['query(e_activity("PTK2", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0394s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0916s
# [INFO] Total time: 1.7827s
# Finished inference (['query(e_activity("PTK2", "Ulixertinib", _)).'])...
# ['query(e_activity("PTPRG", "Ulixertinib", _)).']
# 71/78
# Inferring data (['query(e_activity("PTPRG", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0194s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0179s
# [INFO] Total time: 1.6052s
# Finished inference (['query(e_activity("PTPRG", "Ulixertinib", _)).'])...
# ['query(e_activity("SRC", "Ulixertinib", _)).']
# 72/78
# Inferring data (['query(e_activity("SRC", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0252s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0217s
# [INFO] Total time: 1.6563s
# Finished inference (['query(e_activity("SRC", "Ulixertinib", _)).'])...
# ['query(e_activity("ABL1", "Vemurafenib", _)).']
# 73/78
# Inferring data (['query(e_activity("ABL1", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0368s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0373s
# [INFO] Total time: 1.7049s
# Finished inference (['query(e_activity("ABL1", "Vemurafenib", _)).'])...
# ['query(e_activity("FYN", "Vemurafenib", _)).']
# 74/78
# Inferring data (['query(e_activity("FYN", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0076s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0219s
# [INFO] Total time: 1.6756s
# Finished inference (['query(e_activity("FYN", "Vemurafenib", _)).'])...
# ['query(e_activity("HIPK2", "Vemurafenib", _)).']
# 75/78
# Inferring data (['query(e_activity("HIPK2", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0157s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0156s
# [INFO] Total time: 1.5253s
# Finished inference (['query(e_activity("HIPK2", "Vemurafenib", _)).'])...
# ['query(e_activity("PTK2", "Vemurafenib", _)).']
# 76/78
# Inferring data (['query(e_activity("PTK2", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0361s
# [INFO] Cycle breaking: 0.0034s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0859s
# [INFO] Total time: 1.6690s
# Finished inference (['query(e_activity("PTK2", "Vemurafenib", _)).'])...
# ['query(e_activity("PTPRG", "Vemurafenib", _)).']
# 77/78
# Inferring data (['query(e_activity("PTPRG", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0186s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0252s
# [INFO] Total time: 1.5271s
# Finished inference (['query(e_activity("PTPRG", "Vemurafenib", _)).'])...
# ['query(e_activity("SRC", "Vemurafenib", _)).']
# 78/78
# Inferring data (['query(e_activity("SRC", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp2_testing_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_2.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0220s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0258s
# [INFO] Total time: 1.5261s
# Finished inference (['query(e_activity("SRC", "Vemurafenib", _)).'])...
