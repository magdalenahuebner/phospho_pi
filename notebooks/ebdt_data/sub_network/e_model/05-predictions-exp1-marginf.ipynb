# %% [markdown]
# #### Prerequesites:
# * Define schema (make figure)
# * Define structure (make figure)
# * Define schema class in python (src/models/model_schemata.py)
# * Convert schema + structure into model template (models/templates/p_model.pl)
#
# #### Procedure:
# * Load data
# * Adjust model script for lfi accordingly
# * Create evidence file (if I don't need different evidence files, move to builmodel notebook)
# * LFI

# %% [markdown]
# Multiple instances, 1 pst, X enzymes, one sample per instance, multiple enzymes per instance, test how many enzymes can have in one instances, how computing time depends on N p::f for 60 samples

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os
import pickle

from src.models import model_schemata as schema
from src.models import build_model as build
from src.models import parameter_learning as lfi
from src.models import inference as inf
from src.visualization import visualize as viz

# %%
os.chdir('/Users/magdalena/OneDrive - Queen Mary, University of London/bezzlab/research/projects/phospho_pi/')
# os.chdir('/home/mhuebner/Desktop/bezzlab/research/projects/phospho_pi/')

# %% [markdown]
# #### Inference (I)

# %%
# reading csv from files into dict
data = {}
data['e_ksea'] = pd.read_csv('data/processed/ebdt_data/sub_network_e/e_ksea.csv')
data['p_fc'] = pd.read_csv('data/processed/ebdt_data/sub_network_e/p_fc.csv')

# %%
# Adding evidence
model_inference = 'models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl'

# %% [markdown]
# Adding queries

# %%
sample_ids = data['e_ksea']['sample'].unique().tolist()
enzymes = data['e_ksea']['enzyme'].unique().tolist()
queries = inf.generate_queries(schema.EActivityPredicate, sample_ids=sample_ids, enzymes=enzymes)
len(queries)
# Out:
# 366

# %%
queries[:10]
# Out:
# ['query(e_activity("ABL1", "AC220", _)).',
#  'query(e_activity("FYN", "AC220", _)).',
#  'query(e_activity("HIPK2", "AC220", _)).',
#  'query(e_activity("PTK2", "AC220", _)).',
#  'query(e_activity("PTPRG", "AC220", _)).',
#  'query(e_activity("SRC", "AC220", _)).',
#  'query(e_activity("ABL1", "AT13148", _)).',
#  'query(e_activity("FYN", "AT13148", _)).',
#  'query(e_activity("HIPK2", "AT13148", _)).',
#  'query(e_activity("PTK2", "AT13148", _)).']

# %% [markdown]
# Adding evidence (all phosphosites)

# %%
data['p_regulates'] = pd.read_csv('data/processed/ebdt_data/sub_network_e/p_regulates.csv')

# %%
# Mapping data to Problog predicates
predicates = {}
predicates['p_fc'] = schema.PFoldChangePredicate()
predicates['p_fc'].add_data(data['p_fc'], 'phosphosite', 'sample', 'value')
predicates['e_ksea'] = schema.EKseaPredicate()
predicates['e_ksea'].add_data(data['e_ksea'], 'enzyme', 'sample', 'value')

# %%
evidence_dict = {}
for s in sample_ids:
    evidence_dict[s] = {}
    for e in enzymes:
        phosphosites = data['p_regulates']['phosphosite'][data['p_regulates']['protein'] == e].tolist()
        evid_generator = build.ProblogStatementGenerator(predicates['p_fc'])
        evidence_p = []
        for p in phosphosites:
            evidence_p.extend(evid_generator.generate_facts(build.EvidenceTemplate, select=[s, p]))
        evid_generator = build.ProblogStatementGenerator(predicates['e_ksea'])
        evidence_e = evid_generator.generate_facts(build.EvidenceTemplate, select=[s, e])
        evidence_dict[s][e] = evidence_p + evidence_e

# %%
# make evidence_dict['AZD5438'] into list
evidence_list = []
for s in evidence_dict.keys():
    for e in evidence_dict[s]:
        evidence_list.append(evidence_dict[s][e])
evidence_list[:10]
# Out:
# [['evidence(p_fc("ABL1(S569)", "AC220", inc)).',
#   'evidence(p_fc("ABL1(S718)", "AC220", inc)).',
#   'evidence(p_fc("ABL1(T735)", "AC220", inc)).',
#   'evidence(e_ksea("ABL1", "AC220", inc)).'],
#  ['evidence(e_ksea("FYN", "AC220", dec)).'],
#  ['evidence(p_fc("HIPK2(Y361)", "AC220", inc)).',
#   'evidence(e_ksea("HIPK2", "AC220", dec)).'],
#  ['evidence(p_fc("PTK2(S29)", "AC220", dec)).',
#   'evidence(p_fc("PTK2(S722)", "AC220", dec)).',
#   'evidence(p_fc("PTK2(S910)", "AC220", inc)).',
#   'evidence(p_fc("PTK2(S843)", "AC220", dec)).',
#   'evidence(e_ksea("PTK2", "AC220", inc)).'],
#  ['evidence(p_fc("PTPRG(S995)", "AC220", inc)).',
#   'evidence(e_ksea("PTPRG", "AC220", dec)).'],
#  ['evidence(p_fc("SRC(S17)", "AC220", dec)).',
#   'evidence(p_fc("SRC(S75)", "AC220", dec)).',
#   'evidence(e_ksea("SRC", "AC220", inc)).'],
#  ['evidence(p_fc("ABL1(S569)", "AT13148", inc)).',
#   'evidence(p_fc("ABL1(S718)", "AT13148", dec)).',
#   'evidence(p_fc("ABL1(T735)", "AT13148", inc)).',
#   'evidence(e_ksea("ABL1", "AT13148", inc)).'],
#  ['evidence(e_ksea("FYN", "AT13148", inc)).'],
#  ['evidence(p_fc("HIPK2(Y361)", "AT13148", inc)).',
#   'evidence(e_ksea("HIPK2", "AT13148", dec)).'],
#  ['evidence(p_fc("PTK2(S29)", "AT13148", inc)).',
#   'evidence(p_fc("PTK2(S722)", "AT13148", dec)).',
#   'evidence(p_fc("PTK2(S910)", "AT13148", inc)).',
#   'evidence(p_fc("PTK2(S843)", "AT13148", dec)).',
#   'evidence(e_ksea("PTK2", "AT13148", inc)).']]

# %%
inference_output = 'models/ebdt_data/sub_network/e_model/inference_log_1.txt'
inf_data_dict = inf.infer_marginf(model_inference, queries, inference_output, evidence=evidence_list)
pickle.dump(inf_data_dict, open('models/ebdt_data/sub_network/e_model/predictions_marginf_exp1_100i.pkl', 'wb'))
# Out:
# ['query(e_activity("ABL1", "AC220", _)).']
# 1/366
# Inferring data (['query(e_activity("ABL1", "AC220", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0332s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0344s
# [INFO] Total time: 1.8201s
# Finished inference (['query(e_activity("ABL1", "AC220", _)).'])...
# ['query(e_activity("FYN", "AC220", _)).']
# 2/366
# Inferring data (['query(e_activity("FYN", "AC220", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0086s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0115s
# [INFO] Total time: 1.7955s
# Finished inference (['query(e_activity("FYN", "AC220", _)).'])...
# ['query(e_activity("HIPK2", "AC220", _)).']
# 3/366
# Inferring data (['query(e_activity("HIPK2", "AC220", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0180s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0160s
# [INFO] Total time: 1.6800s
# Finished inference (['query(e_activity("HIPK2", "AC220", _)).'])...
# ['query(e_activity("PTK2", "AC220", _)).']
# 4/366
# Inferring data (['query(e_activity("PTK2", "AC220", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0449s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0938s
# [INFO] Total time: 1.7800s
# Finished inference (['query(e_activity("PTK2", "AC220", _)).'])...
# ['query(e_activity("PTPRG", "AC220", _)).']
# 5/366
# Inferring data (['query(e_activity("PTPRG", "AC220", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0195s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0165s
# [INFO] Total time: 1.7019s
# Finished inference (['query(e_activity("PTPRG", "AC220", _)).'])...
# ['query(e_activity("SRC", "AC220", _)).']
# 6/366
# Inferring data (['query(e_activity("SRC", "AC220", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0307s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0194s
# [INFO] Total time: 1.6980s
# Finished inference (['query(e_activity("SRC", "AC220", _)).'])...
# ['query(e_activity("ABL1", "AT13148", _)).']
# 7/366
# Inferring data (['query(e_activity("ABL1", "AT13148", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0343s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0354s
# [INFO] Total time: 2.8562s
# Finished inference (['query(e_activity("ABL1", "AT13148", _)).'])...
# ['query(e_activity("FYN", "AT13148", _)).']
# 8/366
# Inferring data (['query(e_activity("FYN", "AT13148", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0081s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0108s
# [INFO] Total time: 1.7088s
# Finished inference (['query(e_activity("FYN", "AT13148", _)).'])...
# ['query(e_activity("HIPK2", "AT13148", _)).']
# 9/366
# Inferring data (['query(e_activity("HIPK2", "AT13148", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0175s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0141s
# [INFO] Total time: 1.6228s
# Finished inference (['query(e_activity("HIPK2", "AT13148", _)).'])...
# ['query(e_activity("PTK2", "AT13148", _)).']
# 10/366
# Inferring data (['query(e_activity("PTK2", "AT13148", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0384s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0892s
# [INFO] Total time: 1.8140s
# Finished inference (['query(e_activity("PTK2", "AT13148", _)).'])...
# ['query(e_activity("PTPRG", "AT13148", _)).']
# 11/366
# Inferring data (['query(e_activity("PTPRG", "AT13148", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0661s
# [INFO] Cycle breaking: 0.0062s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0550s
# [INFO] Total time: 3.5008s
# Finished inference (['query(e_activity("PTPRG", "AT13148", _)).'])...
# ['query(e_activity("SRC", "AT13148", _)).']
# 12/366
# Inferring data (['query(e_activity("SRC", "AT13148", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0217s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0161s
# [INFO] Total time: 1.7790s
# Finished inference (['query(e_activity("SRC", "AT13148", _)).'])...
# ['query(e_activity("ABL1", "AZ20", _)).']
# 13/366
# Inferring data (['query(e_activity("ABL1", "AZ20", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0300s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0320s
# [INFO] Total time: 1.6712s
# Finished inference (['query(e_activity("ABL1", "AZ20", _)).'])...
# ['query(e_activity("FYN", "AZ20", _)).']
# 14/366
# Inferring data (['query(e_activity("FYN", "AZ20", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0088s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0180s
# [INFO] Total time: 2.1078s
# Finished inference (['query(e_activity("FYN", "AZ20", _)).'])...
# ['query(e_activity("HIPK2", "AZ20", _)).']
# 15/366
# Inferring data (['query(e_activity("HIPK2", "AZ20", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0173s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0144s
# [INFO] Total time: 1.6367s
# Finished inference (['query(e_activity("HIPK2", "AZ20", _)).'])...
# ['query(e_activity("PTK2", "AZ20", _)).']
# 16/366
# Inferring data (['query(e_activity("PTK2", "AZ20", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0379s
# [INFO] Cycle breaking: 0.0038s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0905s
# [INFO] Total time: 1.7289s
# Finished inference (['query(e_activity("PTK2", "AZ20", _)).'])...
# ['query(e_activity("PTPRG", "AZ20", _)).']
# 17/366
# Inferring data (['query(e_activity("PTPRG", "AZ20", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0188s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0164s
# [INFO] Total time: 1.5508s
# Finished inference (['query(e_activity("PTPRG", "AZ20", _)).'])...
# ['query(e_activity("SRC", "AZ20", _)).']
# 18/366
# Inferring data (['query(e_activity("SRC", "AZ20", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0230s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0175s
# [INFO] Total time: 1.5655s
# Finished inference (['query(e_activity("SRC", "AZ20", _)).'])...
# ['query(e_activity("ABL1", "AZD1480", _)).']
# 19/366
# Inferring data (['query(e_activity("ABL1", "AZD1480", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0312s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0313s
# [INFO] Total time: 1.6098s
# Finished inference (['query(e_activity("ABL1", "AZD1480", _)).'])...
# ['query(e_activity("FYN", "AZD1480", _)).']
# 20/366
# Inferring data (['query(e_activity("FYN", "AZD1480", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0084s
# [INFO] Cycle breaking: 0.0005s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0110s
# [INFO] Total time: 1.5843s
# Finished inference (['query(e_activity("FYN", "AZD1480", _)).'])...
# ['query(e_activity("HIPK2", "AZD1480", _)).']
# 21/366
# Inferring data (['query(e_activity("HIPK2", "AZD1480", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0181s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0152s
# [INFO] Total time: 1.6584s
# Finished inference (['query(e_activity("HIPK2", "AZD1480", _)).'])...
# ['query(e_activity("PTK2", "AZD1480", _)).']
# 22/366
# Inferring data (['query(e_activity("PTK2", "AZD1480", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.1231s
# [INFO] Cycle breaking: 0.0046s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1283s
# [INFO] Total time: 3.1187s
# Finished inference (['query(e_activity("PTK2", "AZD1480", _)).'])...
# ['query(e_activity("PTPRG", "AZD1480", _)).']
# 23/366
# Inferring data (['query(e_activity("PTPRG", "AZD1480", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0251s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0209s
# [INFO] Total time: 2.4188s
# Finished inference (['query(e_activity("PTPRG", "AZD1480", _)).'])...
# ['query(e_activity("SRC", "AZD1480", _)).']
# 24/366
# Inferring data (['query(e_activity("SRC", "AZD1480", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0223s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0177s
# [INFO] Total time: 1.8255s
# Finished inference (['query(e_activity("SRC", "AZD1480", _)).'])...
# ['query(e_activity("ABL1", "AZD3759", _)).']
# 25/366
# Inferring data (['query(e_activity("ABL1", "AZD3759", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0700s
# [INFO] Cycle breaking: 0.0056s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0347s
# [INFO] Total time: 2.0576s
# Finished inference (['query(e_activity("ABL1", "AZD3759", _)).'])...
# ['query(e_activity("FYN", "AZD3759", _)).']
# 26/366
# Inferring data (['query(e_activity("FYN", "AZD3759", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0091s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0145s
# [INFO] Total time: 1.7589s
# Finished inference (['query(e_activity("FYN", "AZD3759", _)).'])...
# ['query(e_activity("HIPK2", "AZD3759", _)).']
# 27/366
# Inferring data (['query(e_activity("HIPK2", "AZD3759", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0194s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0184s
# [INFO] Total time: 1.6885s
# Finished inference (['query(e_activity("HIPK2", "AZD3759", _)).'])...
# ['query(e_activity("PTK2", "AZD3759", _)).']
# 28/366
# Inferring data (['query(e_activity("PTK2", "AZD3759", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0429s
# [INFO] Cycle breaking: 0.0043s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0970s
# [INFO] Total time: 1.9757s
# Finished inference (['query(e_activity("PTK2", "AZD3759", _)).'])...
# ['query(e_activity("PTPRG", "AZD3759", _)).']
# 29/366
# Inferring data (['query(e_activity("PTPRG", "AZD3759", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0194s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0187s
# [INFO] Total time: 1.7383s
# Finished inference (['query(e_activity("PTPRG", "AZD3759", _)).'])...
# ['query(e_activity("SRC", "AZD3759", _)).']
# 30/366
# Inferring data (['query(e_activity("SRC", "AZD3759", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0228s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0174s
# [INFO] Total time: 1.7085s
# Finished inference (['query(e_activity("SRC", "AZD3759", _)).'])...
# ['query(e_activity("ABL1", "AZD5363", _)).']
# 31/366
# Inferring data (['query(e_activity("ABL1", "AZD5363", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0338s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0351s
# [INFO] Total time: 1.7139s
# Finished inference (['query(e_activity("ABL1", "AZD5363", _)).'])...
# ['query(e_activity("FYN", "AZD5363", _)).']
# 32/366
# Inferring data (['query(e_activity("FYN", "AZD5363", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0084s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0112s
# [INFO] Total time: 1.9783s
# Finished inference (['query(e_activity("FYN", "AZD5363", _)).'])...
# ['query(e_activity("HIPK2", "AZD5363", _)).']
# 33/366
# Inferring data (['query(e_activity("HIPK2", "AZD5363", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0202s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0164s
# [INFO] Total time: 2.0729s
# Finished inference (['query(e_activity("HIPK2", "AZD5363", _)).'])...
# ['query(e_activity("PTK2", "AZD5363", _)).']
# 34/366
# Inferring data (['query(e_activity("PTK2", "AZD5363", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0421s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0963s
# [INFO] Total time: 1.9973s
# Finished inference (['query(e_activity("PTK2", "AZD5363", _)).'])...
# ['query(e_activity("PTPRG", "AZD5363", _)).']
# 35/366
# Inferring data (['query(e_activity("PTPRG", "AZD5363", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0214s
# [INFO] Cycle breaking: 0.0021s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0173s
# [INFO] Total time: 1.7559s
# Finished inference (['query(e_activity("PTPRG", "AZD5363", _)).'])...
# ['query(e_activity("SRC", "AZD5363", _)).']
# 36/366
# Inferring data (['query(e_activity("SRC", "AZD5363", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0237s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0182s
# [INFO] Total time: 1.6825s
# Finished inference (['query(e_activity("SRC", "AZD5363", _)).'])...
# ['query(e_activity("ABL1", "AZD5438", _)).']
# 37/366
# Inferring data (['query(e_activity("ABL1", "AZD5438", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0337s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0344s
# [INFO] Total time: 1.7458s
# Finished inference (['query(e_activity("ABL1", "AZD5438", _)).'])...
# ['query(e_activity("FYN", "AZD5438", _)).']
# 38/366
# Inferring data (['query(e_activity("FYN", "AZD5438", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0091s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0111s
# [INFO] Total time: 1.9311s
# Finished inference (['query(e_activity("FYN", "AZD5438", _)).'])...
# ['query(e_activity("HIPK2", "AZD5438", _)).']
# 39/366
# Inferring data (['query(e_activity("HIPK2", "AZD5438", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0383s
# [INFO] Cycle breaking: 0.0030s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0267s
# [INFO] Total time: 1.9626s
# Finished inference (['query(e_activity("HIPK2", "AZD5438", _)).'])...
# ['query(e_activity("PTK2", "AZD5438", _)).']
# 40/366
# Inferring data (['query(e_activity("PTK2", "AZD5438", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0374s
# [INFO] Cycle breaking: 0.0040s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0881s
# [INFO] Total time: 1.9701s
# Finished inference (['query(e_activity("PTK2", "AZD5438", _)).'])...
# ['query(e_activity("PTPRG", "AZD5438", _)).']
# 41/366
# Inferring data (['query(e_activity("PTPRG", "AZD5438", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0192s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0162s
# [INFO] Total time: 1.7794s
# Finished inference (['query(e_activity("PTPRG", "AZD5438", _)).'])...
# ['query(e_activity("SRC", "AZD5438", _)).']
# 42/366
# Inferring data (['query(e_activity("SRC", "AZD5438", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0229s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0167s
# [INFO] Total time: 1.6420s
# Finished inference (['query(e_activity("SRC", "AZD5438", _)).'])...
# ['query(e_activity("ABL1", "AZD6482", _)).']
# 43/366
# Inferring data (['query(e_activity("ABL1", "AZD6482", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0322s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0323s
# [INFO] Total time: 1.7231s
# Finished inference (['query(e_activity("ABL1", "AZD6482", _)).'])...
# ['query(e_activity("FYN", "AZD6482", _)).']
# 44/366
# Inferring data (['query(e_activity("FYN", "AZD6482", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0085s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0132s
# [INFO] Total time: 2.0926s
# Finished inference (['query(e_activity("FYN", "AZD6482", _)).'])...
# ['query(e_activity("HIPK2", "AZD6482", _)).']
# 45/366
# Inferring data (['query(e_activity("HIPK2", "AZD6482", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0206s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0149s
# [INFO] Total time: 1.8900s
# Finished inference (['query(e_activity("HIPK2", "AZD6482", _)).'])...
# ['query(e_activity("PTK2", "AZD6482", _)).']
# 46/366
# Inferring data (['query(e_activity("PTK2", "AZD6482", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0395s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1011s
# [INFO] Total time: 2.0117s
# Finished inference (['query(e_activity("PTK2", "AZD6482", _)).'])...
# ['query(e_activity("PTPRG", "AZD6482", _)).']
# 47/366
# Inferring data (['query(e_activity("PTPRG", "AZD6482", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0202s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0174s
# [INFO] Total time: 1.6093s
# Finished inference (['query(e_activity("PTPRG", "AZD6482", _)).'])...
# ['query(e_activity("SRC", "AZD6482", _)).']
# 48/366
# Inferring data (['query(e_activity("SRC", "AZD6482", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0223s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0181s
# [INFO] Total time: 1.6769s
# Finished inference (['query(e_activity("SRC", "AZD6482", _)).'])...
# ['query(e_activity("ABL1", "AZD6738", _)).']
# 49/366
# Inferring data (['query(e_activity("ABL1", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0363s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0341s
# [INFO] Total time: 1.7716s
# Finished inference (['query(e_activity("ABL1", "AZD6738", _)).'])...
# ['query(e_activity("FYN", "AZD6738", _)).']
# 50/366
# Inferring data (['query(e_activity("FYN", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0079s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0110s
# [INFO] Total time: 1.7612s
# Finished inference (['query(e_activity("FYN", "AZD6738", _)).'])...
# ['query(e_activity("HIPK2", "AZD6738", _)).']
# 51/366
# Inferring data (['query(e_activity("HIPK2", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0164s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0201s
# [INFO] Total time: 1.7784s
# Finished inference (['query(e_activity("HIPK2", "AZD6738", _)).'])...
# ['query(e_activity("PTK2", "AZD6738", _)).']
# 52/366
# Inferring data (['query(e_activity("PTK2", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0397s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0913s
# [INFO] Total time: 1.8082s
# Finished inference (['query(e_activity("PTK2", "AZD6738", _)).'])...
# ['query(e_activity("PTPRG", "AZD6738", _)).']
# 53/366
# Inferring data (['query(e_activity("PTPRG", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0206s
# [INFO] Cycle breaking: 0.0023s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0207s
# [INFO] Total time: 1.8014s
# Finished inference (['query(e_activity("PTPRG", "AZD6738", _)).'])...
# ['query(e_activity("SRC", "AZD6738", _)).']
# 54/366
# Inferring data (['query(e_activity("SRC", "AZD6738", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0258s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0201s
# [INFO] Total time: 1.9811s
# Finished inference (['query(e_activity("SRC", "AZD6738", _)).'])...
# ['query(e_activity("ABL1", "AZD8055", _)).']
# 55/366
# Inferring data (['query(e_activity("ABL1", "AZD8055", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0532s
# [INFO] Cycle breaking: 0.0048s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0540s
# [INFO] Total time: 2.0842s
# Finished inference (['query(e_activity("ABL1", "AZD8055", _)).'])...
# ['query(e_activity("FYN", "AZD8055", _)).']
# 56/366
# Inferring data (['query(e_activity("FYN", "AZD8055", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0096s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0111s
# [INFO] Total time: 2.2761s
# Finished inference (['query(e_activity("FYN", "AZD8055", _)).'])...
# ['query(e_activity("HIPK2", "AZD8055", _)).']
# 57/366
# Inferring data (['query(e_activity("HIPK2", "AZD8055", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0169s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0169s
# [INFO] Total time: 1.8123s
# Finished inference (['query(e_activity("HIPK2", "AZD8055", _)).'])...
# ['query(e_activity("PTK2", "AZD8055", _)).']
# 58/366
# Inferring data (['query(e_activity("PTK2", "AZD8055", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0381s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0936s
# [INFO] Total time: 1.9136s
# Finished inference (['query(e_activity("PTK2", "AZD8055", _)).'])...
# ['query(e_activity("PTPRG", "AZD8055", _)).']
# 59/366
# Inferring data (['query(e_activity("PTPRG", "AZD8055", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0261s
# [INFO] Cycle breaking: 0.0026s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0193s
# [INFO] Total time: 2.5693s
# Finished inference (['query(e_activity("PTPRG", "AZD8055", _)).'])...
# ['query(e_activity("SRC", "AZD8055", _)).']
# 60/366
# Inferring data (['query(e_activity("SRC", "AZD8055", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0242s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0177s
# [INFO] Total time: 1.9780s
# Finished inference (['query(e_activity("SRC", "AZD8055", _)).'])...
# ['query(e_activity("ABL1", "Amuvatinib", _)).']
# 61/366
# Inferring data (['query(e_activity("ABL1", "Amuvatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0299s
# [INFO] Cycle breaking: 0.0029s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0318s
# [INFO] Total time: 1.7071s
# Finished inference (['query(e_activity("ABL1", "Amuvatinib", _)).'])...
# ['query(e_activity("FYN", "Amuvatinib", _)).']
# 62/366
# Inferring data (['query(e_activity("FYN", "Amuvatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0078s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0106s
# [INFO] Total time: 1.6618s
# Finished inference (['query(e_activity("FYN", "Amuvatinib", _)).'])...
# ['query(e_activity("HIPK2", "Amuvatinib", _)).']
# 63/366
# Inferring data (['query(e_activity("HIPK2", "Amuvatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0188s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0229s
# [INFO] Total time: 1.9286s
# Finished inference (['query(e_activity("HIPK2", "Amuvatinib", _)).'])...
# ['query(e_activity("PTK2", "Amuvatinib", _)).']
# 64/366
# Inferring data (['query(e_activity("PTK2", "Amuvatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0422s
# [INFO] Cycle breaking: 0.0042s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0902s
# [INFO] Total time: 1.8992s
# Finished inference (['query(e_activity("PTK2", "Amuvatinib", _)).'])...
# ['query(e_activity("PTPRG", "Amuvatinib", _)).']
# 65/366
# Inferring data (['query(e_activity("PTPRG", "Amuvatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0182s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0166s
# [INFO] Total time: 1.6699s
# Finished inference (['query(e_activity("PTPRG", "Amuvatinib", _)).'])...
# ['query(e_activity("SRC", "Amuvatinib", _)).']
# 66/366
# Inferring data (['query(e_activity("SRC", "Amuvatinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0371s
# [INFO] Cycle breaking: 0.0042s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0255s
# [INFO] Total time: 2.5556s
# Finished inference (['query(e_activity("SRC", "Amuvatinib", _)).'])...
# ['query(e_activity("ABL1", "BX912", _)).']
# 67/366
# Inferring data (['query(e_activity("ABL1", "BX912", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0348s
# [INFO] Cycle breaking: 0.0032s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0355s
# [INFO] Total time: 2.2842s
# Finished inference (['query(e_activity("ABL1", "BX912", _)).'])...
# ['query(e_activity("FYN", "BX912", _)).']
# 68/366
# Inferring data (['query(e_activity("FYN", "BX912", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0085s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0137s
# [INFO] Total time: 1.8300s
# Finished inference (['query(e_activity("FYN", "BX912", _)).'])...
# ['query(e_activity("HIPK2", "BX912", _)).']
# 69/366
# Inferring data (['query(e_activity("HIPK2", "BX912", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0177s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0152s
# [INFO] Total time: 1.7930s
# Finished inference (['query(e_activity("HIPK2", "BX912", _)).'])...
# ['query(e_activity("PTK2", "BX912", _)).']
# 70/366
# Inferring data (['query(e_activity("PTK2", "BX912", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0433s
# [INFO] Cycle breaking: 0.0040s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0934s
# [INFO] Total time: 1.9178s
# Finished inference (['query(e_activity("PTK2", "BX912", _)).'])...
# ['query(e_activity("PTPRG", "BX912", _)).']
# 71/366
# Inferring data (['query(e_activity("PTPRG", "BX912", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0223s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0193s
# [INFO] Total time: 2.0131s
# Finished inference (['query(e_activity("PTPRG", "BX912", _)).'])...
# ['query(e_activity("SRC", "BX912", _)).']
# 72/366
# Inferring data (['query(e_activity("SRC", "BX912", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0245s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0194s
# [INFO] Total time: 1.7947s
# Finished inference (['query(e_activity("SRC", "BX912", _)).'])...
# ['query(e_activity("ABL1", "Bosutinib", _)).']
# 73/366
# Inferring data (['query(e_activity("ABL1", "Bosutinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0378s
# [INFO] Cycle breaking: 0.0033s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0344s
# [INFO] Total time: 1.8373s
# Finished inference (['query(e_activity("ABL1", "Bosutinib", _)).'])...
# ['query(e_activity("FYN", "Bosutinib", _)).']
# 74/366
# Inferring data (['query(e_activity("FYN", "Bosutinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0107s
# [INFO] Cycle breaking: 0.0006s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0204s
# [INFO] Total time: 1.9470s
# Finished inference (['query(e_activity("FYN", "Bosutinib", _)).'])...
# ['query(e_activity("HIPK2", "Bosutinib", _)).']
# 75/366
# Inferring data (['query(e_activity("HIPK2", "Bosutinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0301s
# [INFO] Cycle breaking: 0.0018s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0267s
# [INFO] Total time: 2.7575s
# Finished inference (['query(e_activity("HIPK2", "Bosutinib", _)).'])...
# ['query(e_activity("PTK2", "Bosutinib", _)).']
# 76/366
# Inferring data (['query(e_activity("PTK2", "Bosutinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0467s
# [INFO] Cycle breaking: 0.0042s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.1007s
# [INFO] Total time: 2.3778s
# Finished inference (['query(e_activity("PTK2", "Bosutinib", _)).'])...
# ['query(e_activity("PTPRG", "Bosutinib", _)).']
# 77/366
# Inferring data (['query(e_activity("PTPRG", "Bosutinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0188s
# [INFO] Cycle breaking: 0.0025s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0193s
# [INFO] Total time: 1.8492s
# Finished inference (['query(e_activity("PTPRG", "Bosutinib", _)).'])...
# ['query(e_activity("SRC", "Bosutinib", _)).']
# 78/366
# Inferring data (['query(e_activity("SRC", "Bosutinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0274s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0196s
# [INFO] Total time: 1.8037s
# Finished inference (['query(e_activity("SRC", "Bosutinib", _)).'])...
# ['query(e_activity("ABL1", "CAL101", _)).']
# 79/366
# Inferring data (['query(e_activity("ABL1", "CAL101", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0360s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0343s
# [INFO] Total time: 1.7911s
# Finished inference (['query(e_activity("ABL1", "CAL101", _)).'])...
# ['query(e_activity("FYN", "CAL101", _)).']
# 80/366
# Inferring data (['query(e_activity("FYN", "CAL101", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0108s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0119s
# [INFO] Total time: 1.8659s
# Finished inference (['query(e_activity("FYN", "CAL101", _)).'])...
# ['query(e_activity("HIPK2", "CAL101", _)).']
# 81/366
# Inferring data (['query(e_activity("HIPK2", "CAL101", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0192s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0167s
# [INFO] Total time: 2.0916s
# Finished inference (['query(e_activity("HIPK2", "CAL101", _)).'])...
# ['query(e_activity("PTK2", "CAL101", _)).']
# 82/366
# Inferring data (['query(e_activity("PTK2", "CAL101", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0486s
# [INFO] Cycle breaking: 0.0039s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0961s
# [INFO] Total time: 2.0871s
# Finished inference (['query(e_activity("PTK2", "CAL101", _)).'])...
# ['query(e_activity("PTPRG", "CAL101", _)).']
# 83/366
# Inferring data (['query(e_activity("PTPRG", "CAL101", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0219s
# [INFO] Cycle breaking: 0.0020s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0192s
# [INFO] Total time: 1.7859s
# Finished inference (['query(e_activity("PTPRG", "CAL101", _)).'])...
# ['query(e_activity("SRC", "CAL101", _)).']
# 84/366
# Inferring data (['query(e_activity("SRC", "CAL101", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0266s
# [INFO] Cycle breaking: 0.0034s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0187s
# [INFO] Total time: 2.2810s
# Finished inference (['query(e_activity("SRC", "CAL101", _)).'])...
# ['query(e_activity("ABL1", "CHIR99021", _)).']
# 85/366
# Inferring data (['query(e_activity("ABL1", "CHIR99021", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0308s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0383s
# [INFO] Total time: 1.8397s
# Finished inference (['query(e_activity("ABL1", "CHIR99021", _)).'])...
# ['query(e_activity("FYN", "CHIR99021", _)).']
# 86/366
# Inferring data (['query(e_activity("FYN", "CHIR99021", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0083s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0099s
# [INFO] Total time: 1.6799s
# Finished inference (['query(e_activity("FYN", "CHIR99021", _)).'])...
# ['query(e_activity("HIPK2", "CHIR99021", _)).']
# 87/366
# Inferring data (['query(e_activity("HIPK2", "CHIR99021", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0170s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0139s
# [INFO] Total time: 1.7184s
# Finished inference (['query(e_activity("HIPK2", "CHIR99021", _)).'])...
# ['query(e_activity("PTK2", "CHIR99021", _)).']
# 88/366
# ...
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0078s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0101s
# [INFO] Total time: 1.5471s
# Finished inference (['query(e_activity("FYN", "Torin", _)).'])...
# ['query(e_activity("HIPK2", "Torin", _)).']
# 339/366
# Inferring data (['query(e_activity("HIPK2", "Torin", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0164s
# [INFO] Cycle breaking: 0.0016s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0150s
# [INFO] Total time: 1.5471s
# Finished inference (['query(e_activity("HIPK2", "Torin", _)).'])...
# ['query(e_activity("PTK2", "Torin", _)).']
# 340/366
# Inferring data (['query(e_activity("PTK2", "Torin", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0381s
# [INFO] Cycle breaking: 0.0036s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0855s
# [INFO] Total time: 1.7053s
# Finished inference (['query(e_activity("PTK2", "Torin", _)).'])...
# ['query(e_activity("PTPRG", "Torin", _)).']
# 341/366
# Inferring data (['query(e_activity("PTPRG", "Torin", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0191s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0165s
# [INFO] Total time: 1.5249s
# Finished inference (['query(e_activity("PTPRG", "Torin", _)).'])...
# ['query(e_activity("SRC", "Torin", _)).']
# 342/366
# Inferring data (['query(e_activity("SRC", "Torin", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0219s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0163s
# [INFO] Total time: 1.5132s
# Finished inference (['query(e_activity("SRC", "Torin", _)).'])...
# ['query(e_activity("ABL1", "Trametinib", _)).']
# 343/366
# Inferring data (['query(e_activity("ABL1", "Trametinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0309s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0306s
# [INFO] Total time: 1.6547s
# Finished inference (['query(e_activity("ABL1", "Trametinib", _)).'])...
# ['query(e_activity("FYN", "Trametinib", _)).']
# 344/366
# Inferring data (['query(e_activity("FYN", "Trametinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0078s
# [INFO] Cycle breaking: 0.0004s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0097s
# [INFO] Total time: 1.5075s
# Finished inference (['query(e_activity("FYN", "Trametinib", _)).'])...
# ['query(e_activity("HIPK2", "Trametinib", _)).']
# 345/366
# Inferring data (['query(e_activity("HIPK2", "Trametinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0162s
# [INFO] Cycle breaking: 0.0015s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0136s
# [INFO] Total time: 1.5328s
# Finished inference (['query(e_activity("HIPK2", "Trametinib", _)).'])...
# ['query(e_activity("PTK2", "Trametinib", _)).']
# 346/366
# Inferring data (['query(e_activity("PTK2", "Trametinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0741s
# [INFO] Cycle breaking: 0.0068s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.1672s
# [INFO] Total time: 3.3722s
# Finished inference (['query(e_activity("PTK2", "Trametinib", _)).'])...
# ['query(e_activity("PTPRG", "Trametinib", _)).']
# 347/366
# Inferring data (['query(e_activity("PTPRG", "Trametinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0347s
# [INFO] Cycle breaking: 0.0037s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0299s
# [INFO] Total time: 3.0202s
# Finished inference (['query(e_activity("PTPRG", "Trametinib", _)).'])...
# ['query(e_activity("SRC", "Trametinib", _)).']
# 348/366
# Inferring data (['query(e_activity("SRC", "Trametinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0420s
# [INFO] Cycle breaking: 0.0048s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0300s
# [INFO] Total time: 3.0840s
# Finished inference (['query(e_activity("SRC", "Trametinib", _)).'])...
# ['query(e_activity("ABL1", "U73122", _)).']
# 349/366
# Inferring data (['query(e_activity("ABL1", "U73122", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0601s
# [INFO] Cycle breaking: 0.0054s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0580s
# [INFO] Total time: 3.0836s
# Finished inference (['query(e_activity("ABL1", "U73122", _)).'])...
# ['query(e_activity("FYN", "U73122", _)).']
# 350/366
# Inferring data (['query(e_activity("FYN", "U73122", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0153s
# [INFO] Cycle breaking: 0.0006s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0188s
# [INFO] Total time: 2.9405s
# Finished inference (['query(e_activity("FYN", "U73122", _)).'])...
# ['query(e_activity("HIPK2", "U73122", _)).']
# 351/366
# Inferring data (['query(e_activity("HIPK2", "U73122", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0319s
# [INFO] Cycle breaking: 0.0028s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0259s
# [INFO] Total time: 2.9724s
# Finished inference (['query(e_activity("HIPK2", "U73122", _)).'])...
# ['query(e_activity("PTK2", "U73122", _)).']
# 352/366
# Inferring data (['query(e_activity("PTK2", "U73122", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0381s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0886s
# [INFO] Total time: 1.9056s
# Finished inference (['query(e_activity("PTK2", "U73122", _)).'])...
# ['query(e_activity("PTPRG", "U73122", _)).']
# 353/366
# Inferring data (['query(e_activity("PTPRG", "U73122", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0183s
# [INFO] Cycle breaking: 0.0019s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0160s
# [INFO] Total time: 1.5341s
# Finished inference (['query(e_activity("PTPRG", "U73122", _)).'])...
# ['query(e_activity("SRC", "U73122", _)).']
# 354/366
# Inferring data (['query(e_activity("SRC", "U73122", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0218s
# [INFO] Cycle breaking: 0.0024s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0163s
# [INFO] Total time: 1.5668s
# Finished inference (['query(e_activity("SRC", "U73122", _)).'])...
# ['query(e_activity("ABL1", "Ulixertinib", _)).']
# 355/366
# Inferring data (['query(e_activity("ABL1", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0307s
# [INFO] Cycle breaking: 0.0027s
# [INFO] Clark's completion: 0.0002s
# [INFO] DSharp compilation: 0.0305s
# [INFO] Total time: 1.5615s
# Finished inference (['query(e_activity("ABL1", "Ulixertinib", _)).'])...
# ['query(e_activity("FYN", "Ulixertinib", _)).']
# 356/366
# Inferring data (['query(e_activity("FYN", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0080s
# [INFO] Cycle breaking: 0.0003s
# [INFO] Clark's completion: 0.0000s
# [INFO] DSharp compilation: 0.0103s
# [INFO] Total time: 1.5074s
# Finished inference (['query(e_activity("FYN", "Ulixertinib", _)).'])...
# ['query(e_activity("HIPK2", "Ulixertinib", _)).']
# 357/366
# Inferring data (['query(e_activity("HIPK2", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0171s
# [INFO] Cycle breaking: 0.0017s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0140s
# [INFO] Total time: 1.5782s
# Finished inference (['query(e_activity("HIPK2", "Ulixertinib", _)).'])...
# ['query(e_activity("PTK2", "Ulixertinib", _)).']
# 358/366
# Inferring data (['query(e_activity("PTK2", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0000s
# [INFO] Grounding: 0.0370s
# [INFO] Cycle breaking: 0.0035s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0877s
# [INFO] Total time: 1.6779s
# Finished inference (['query(e_activity("PTK2", "Ulixertinib", _)).'])...
# ['query(e_activity("PTPRG", "Ulixertinib", _)).']
# 359/366
# Inferring data (['query(e_activity("PTPRG", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0364s
# [INFO] Cycle breaking: 0.0041s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0300s
# [INFO] Total time: 1.9354s
# Finished inference (['query(e_activity("PTPRG", "Ulixertinib", _)).'])...
# ['query(e_activity("SRC", "Ulixertinib", _)).']
# 360/366
# Inferring data (['query(e_activity("SRC", "Ulixertinib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0423s
# [INFO] Cycle breaking: 0.0047s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0297s
# [INFO] Total time: 3.0208s
# Finished inference (['query(e_activity("SRC", "Ulixertinib", _)).'])...
# ['query(e_activity("ABL1", "Vemurafenib", _)).']
# 361/366
# Inferring data (['query(e_activity("ABL1", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0597s
# [INFO] Cycle breaking: 0.0058s
# [INFO] Clark's completion: 0.0004s
# [INFO] DSharp compilation: 0.0586s
# [INFO] Total time: 3.0348s
# Finished inference (['query(e_activity("ABL1", "Vemurafenib", _)).'])...
# ['query(e_activity("FYN", "Vemurafenib", _)).']
# 362/366
# Inferring data (['query(e_activity("FYN", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0150s
# [INFO] Cycle breaking: 0.0006s
# [INFO] Clark's completion: 0.0001s
# [INFO] DSharp compilation: 0.0180s
# [INFO] Total time: 2.9978s
# Finished inference (['query(e_activity("FYN", "Vemurafenib", _)).'])...
# ['query(e_activity("HIPK2", "Vemurafenib", _)).']
# 363/366
# Inferring data (['query(e_activity("HIPK2", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0322s
# [INFO] Cycle breaking: 0.0031s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0254s
# [INFO] Total time: 2.9941s
# Finished inference (['query(e_activity("HIPK2", "Vemurafenib", _)).'])...
# ['query(e_activity("PTK2", "Vemurafenib", _)).']
# 364/366
# Inferring data (['query(e_activity("PTK2", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0748s
# [INFO] Cycle breaking: 0.0068s
# [INFO] Clark's completion: 0.0005s
# [INFO] DSharp compilation: 0.1673s
# [INFO] Total time: 3.2771s
# Finished inference (['query(e_activity("PTK2", "Vemurafenib", _)).'])...
# ['query(e_activity("PTPRG", "Vemurafenib", _)).']
# 365/366
# Inferring data (['query(e_activity("PTPRG", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0365s
# [INFO] Cycle breaking: 0.0038s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0342s
# [INFO] Total time: 3.0519s
# Finished inference (['query(e_activity("PTPRG", "Vemurafenib", _)).'])...
# ['query(e_activity("SRC", "Vemurafenib", _)).']
# 366/366
# Inferring data (['query(e_activity("SRC", "Vemurafenib", _)).'])...
# problog models/ebdt_data/sub_network/e_model/e_model_exp1_inference_100i.pl -o models/ebdt_data/sub_network/e_model/inference_log_1.txt -k ddnnf -v
# [INFO] Output level: INFO
# [INFO] Propagating evidence: 0.0001s
# [INFO] Grounding: 0.0424s
# [INFO] Cycle breaking: 0.0051s
# [INFO] Clark's completion: 0.0003s
# [INFO] DSharp compilation: 0.0450s
# [INFO] Total time: 3.0290s
# Finished inference (['query(e_activity("SRC", "Vemurafenib", _)).'])...
