# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Libraries
import os
import pickle

from src.models import train_model, test_model, predict_model

# %%
# os.chdir('/Users/magdalena/OneDrive - Queen Mary, University of London/bezzlab/research/projects/phospho_pi/')
os.chdir('/home/mhuebner/Desktop/bezzlab/research/projects/phospho_pi/')

# %%
EXPERIMENT = 'mh16'
MODEL = 'model_A2'
EXP_DIR = f'./models/{EXPERIMENT}/'
# Training
PATH_TO_DATA = f'data/processed/synthetic_data/model_A1/n1000/mutate_m1_20_pspec/'
# Models
model_template = f'./models/templates/{MODEL}_noisyor.pl'

# %% [markdown]
# Training

# %%
train_model.main(
    experiment = EXPERIMENT, 
    path_to_data = PATH_TO_DATA, 
    model_template = model_template, 
    training = 0.8, 
    max_iter = 20, 
    evidence = ['occupancy'],
    facts = ['activity', 'fold_change'],
    suffix = ''
)
# Out:
# Splitting data...
# Starting LFI...
# problog lfi ./models/mh16/model.pl ./models/mh16/evidence.pl -O ./models/mh16/model_trained.pl --normalize -k ddnnf -v -n 20
# [INFO] Output level: INFO
# [INFO] Number of examples: 800
# [INFO] Compile time: 10.965409
# [INFO] Weights to learn: [t(0.33,_fc)::occupancy(P,S,inc), t(0.33,_fc)::occupancy(P,S,dec), t(0.33,_fc)::occupancy(P,S,baseline), t(0.33,E,_dM)::occupancy(P,S,inc), t(0.33,E,_dM)::occupancy(P,S,dec), t(0.33,E,_dM)::occupancy(P,S,baseline)]
# [INFO] Bodies: [lfi_body(0,t(_fc),P,S,inc), lfi_body(1,t(_fc),P,S,dec), lfi_body(2,t(_fc),P,S,baseline), lfi_body(3,t(E,_dM),P,S,inc), lfi_body(4,t(E,_dM),P,S,dec), lfi_body(5,t(E,_dM),P,S,baseline)]
# [INFO] Parents: [lfi_par(0,t(_fc),P,S,inc), lfi_par(1,t(_fc),P,S,dec), lfi_par(2,t(_fc),P,S,baseline), lfi_par(3,t(E,_dM),P,S,inc), lfi_par(4,t(E,_dM),P,S,dec), lfi_par(5,t(E,_dM),P,S,baseline)]
# [INFO] Initial weights: [0.33, 0.33, 0.33, 0.33, 0.33, 0.33]
# [INFO]
# [INFO] Iteration 1
# [INFO] Weights after iteration 1: [{t(inc): 0.7446841369055148, t(baseline): 0.19178761701138566, t(dec): 0.1720781299027807}, {t(inc): 0.1561923127805394, t(baseline): 0.1877538154909652, t(dec): 0.6972208682348691}, {t(inc): 0.09912355031394576, t(baseline): 0.6204585674976492, t(dec): 0.13070100186235015}, {t(e2,inc): 0.5336246344687505, t(e3,inc): 0.5502358963336079, t(e1,baseline): 0.3907865619230277, t(e1,dec): 0.22127040614683985, t(e3,dec): 0.2199737979736726, t(e2,baseline): 0.3552801746117921, t(e3,baseline): 0.34629464256188336, t(e2,dec): 0.21565816286166128, t(e1,inc): 0.48740266980503966}, {t(e1,baseline): 0.32623878702311365, t(e2,inc): 0.22481060348458964, t(e3,inc): 0.23036501038430335, t(e1,dec): 0.5227524247581323, t(e3,dec): 0.528773734879443, t(e2,baseline): 0.33433242555347015, t(e3,baseline): 0.3227913353174
# [INFO] 0.9::interaction(e1,p0).
# [INFO] 0.65::interaction(e2,p0).
# [INFO] 0.8::interaction(e3,p0).
# [INFO] modification(E,P,S,inc) :- interaction(E,P), enz_class(E,kinase), activity(E,S,inc).
# [INFO] modification(E,P,S,inc) :- interaction(E,P), enz_class(E,phosphatase), activity(E,S,dec).
# [INFO] modification(E,P,S,dec) :- interaction(E,P), enz_class(E,kinase), activity(E,S,dec).
# [INFO] modification(E,P,S,dec) :- interaction(E,P), enz_class(E,phosphatase), activity(E,S,inc).
# [INFO] modification(E,P,S,baseline) :- interaction(E,P), enz_class(E,kinase), activity(E,S,baseline).
# [INFO] modification(E,P,S,baseline) :- interaction(E,P), enz_class(E,phosphatase), activity(E,S,baseline).
# [INFO] 0.001::occupancy(P,S,inc); 0.001::occupancy(P,S,dec); 0.001::occupancy(P,S,baseline) :- phosphosite(P).
# [INFO] 0.999999982669865::occupancy(P,S,inc); 1.7330135e-08::occupancy(P,S,dec); 0.0::occupancy(P,S,baseline) :- fold_change(P,S,inc).
# [INFO] 0.0::occupancy(P,S,inc); 3.63110684e-06::occupancy(P,S,dec); 0.99999636889316::occupancy(P,S,baseline) :- fold_change(P,S,baseline).
# [INFO] 1.7589872669e-05::occupancy(P,S,inc); 0.999969128311777::occupancy(P,S,dec); 1.3281815553e-05::occupancy(P,S,baseline) :- fold_change(P,S,dec).
# [INFO] 0.994973057493398::occupancy(P,S,inc); 0.000369980665933::occupancy(P,S,dec); 0.004656961840669::occupancy(P,S,baseline) :- modification(e2,P,S,inc).
# [INFO] 0.983258546671653::occupancy(P,S,inc); 0.010653982039514::occupancy(P,S,dec); 0.006087471288833::occupancy(P,S,baseline) :- modification(e3,P,S,inc).
# [INFO] 0.50323723110374::occupancy(P,S,inc); 0.180253706212513::occupancy(P,S,dec); 0.316509062683748::occupancy(P,S,baseline) :- modification(e1,P,S,baseline).
# [INFO] 0.069454209585839::occupancy(P,S,inc); 0.804200556287207::occupancy(P,S,dec); 0.126345234126954::occupancy(P,S,baseline) :- modification(e1,P,S,dec).
# [INFO] 0.022571691314778::occupancy(P,S,inc); 0.936869949719728::occupancy(P,S,dec); 0.040558358965494::occupancy(P,S,baseline) :- modification(e3,P,S,dec).
# [INFO] 0.343571620194795::occupancy(P,S,inc); 0.34852593236126::occupancy(P,S,dec); 0.307902447443945::occupancy(P,S,baseline) :- modification(e2,P,S,baseline).
# [INFO] 0.339367385700975::occupancy(P,S,inc); 0.06375475134811::occupancy(P,S,dec); 0.596877862950915::occupancy(P,S,baseline) :- modification(e3,P,S,baseline).
# [INFO] 0.0032345997774::occupancy(P,S,inc); 0.947272472106374::occupancy(P,S,dec); 0.049492928116225::occupancy(P,S,baseline) :- modification(e2,P,S,dec).
# [INFO] 0.763472596671279::occupancy(P,S,inc); 0.071961786788453::occupancy(P,S,dec); 0.164565616540269::occupancy(P,S,baseline) :- modification(e1,P,S,inc).
# [INFO] 0.500260787358763::activity(e1,s300,baseline).
# [INFO] 0.501951635375039::activity(e3,s43,inc).
# [INFO] 0.502268382049383::activity(e1,s372,baseline).
# [INFO] 0.502462147023721::activity(e3,s804,baseline).
# [INFO] 0.502578520731696::activity(e2,s538,dec).
# [INFO] 0.502609348745401::activity(e1,s535,baseline).
# [INFO] 0.50303040503001::activity(e2,s417,inc).
# [INFO] 0.503398524549038::activity(e1,s603,dec).
# [INFO] 0.504126094180779::activity(e1,s810,inc).
# [INFO] 0.50419984412498::activity(e3,s806,dec).
# [INFO] 0.504576349900232::activity(e1,s785,inc).
# [INFO] 0.504708352791471::activity(e2,s747,baseline).
# [INFO] 0.504810158454862::activity(e3,s171,dec).
# [INFO] 0.504842324764341::activity(e1,s585,inc).
# [INFO] 0.505025192571033::activity(e1,s541,inc).
# [INFO] 0.505327326424066::activity(e2,s283,baseline).
# [INFO] 0.505531952568236::activity(e2,s364,dec).
# [INFO] 0.50695299743113::activity(e1,s266,inc).
# [INFO] 0.508159680159585::activity(e1,s309,inc).
# [INFO] 0.508294082145198::activity(e2,s350,inc).
# [INFO] 0.508362872982679::activity(e3,s476,dec).
# [INFO] 0.508570500403548::activity(e3,s607,dec).
# [INFO] 0.508656020607152::activity(e1,s285,baseline).
# [INFO] 0.50962244428571::activity(e3,s131,dec).
# [INFO] 0.509658391417807::activity(e3,s712,baseline).
# [INFO] 0.510281391992031::activity(e3,s185,dec).
# [INFO] 0.510603953616759::activity(e3,s331,dec).
# [INFO] 0.510679667422825::activity(e2,s193,baseline).
# [INFO] 0.510688865393042::activity(e2,s396,inc).
# [INFO] 0.510987693340761::activity(e1,s509,inc).
# [INFO] 0.512529639680253::activity(e3,s414,inc).
# [INFO] 0.512600199738303::activity(e3,s615,dec).
# [INFO] 0.512826267160005::activity(e3,s320,inc).
# [INFO] 0.513597265414954::activity(e2,s584,inc).
# [INFO] 0.516939119522518::activity(e1,s456,baseline).
# [INFO] 0.517052060073416::activity(e3,s795,dec).
# [INFO] 0.517082319151021::activity(e2,s475,baseline).
# [INFO] 0.517147947740512::activity(e1,s984,dec).
# [INFO] 0.517810549818461::activity(e1,s261,baseline).
# [INFO] 0.51814794282262::activity(e2,s485,dec).
# [INFO] 0.51815032265335::activity(e2,s201,baseline).
# [INFO] 0.518799851803887::activity(e3,s684,baseline).
# [INFO] 0.519780569095583::activity(e2,s395,inc).
# [INFO] 0.519887667796257::activity(e3,s996,dec).
# [INFO] 0.520063839319822::activity(e1,s762,baseline).
# [INFO] 0.520293261947882::activity(e2,s868,dec).
# [INFO] 0.52042945151032::activity(e3,s224,inc).
# [INFO] 0.521544317258473::activity(e3,s471,dec).
# [INFO] 0.521685108775147::activity(e3,s278,baseline).
# [INFO] 0.521736076006438::activity(e1,s661,inc).
# [INFO] 0.523430981893819::activity(e1,s295,baseline).
# [INFO] 0.523667686397217::activity(e1,s608,baseline).
# [INFO] 0.524414639188374::activity(e1,s622,baseline).
# [INFO] 0.524451456386781::activity(e3,s872,inc).
# [INFO] 0.52449875141437::activity(e3,s231,baseline).
# [INFO] 0.524989344283582::activity(e3,s270,inc).
# [INFO] 0.525195504171286::activity(e2,s352,dec).
# [INFO] 0.525595270828006::activity(e2,s819,inc).
# [INFO] 0.52610741773734::activity(e1,s717,dec).
# [INFO] 0.526145486025997::activity(e1,s607,baseline).
# [INFO] 0.52745792620882::activity(e2,s870,dec).
# [INFO] 0.527686711874158::activity(e1,s107,inc).
# [INFO] 0.528088207369435::activity(e3,s668,dec).
# [INFO] 0.528228317206849::activity(e1,s416,inc).
# [INFO] 0.52854614332478::activity(e2,s11,dec).
# [INFO] 0.528815469857061::activity(e2,s119,baseline).
# [INFO] 0.529320005473087::activity(e2,s956,baseline).
# [INFO] 0.52944731494412::activity(e1,s420,baseline).
# [INFO] 0.531384192176961::activity(e3,s821,inc).
# [INFO] 0.532407579399298::activity(e2,s452,baseline).
# [INFO] 0.53447145352267::activity(e1,s837,inc).
# [INFO] 0.534668817574709::activity(e2,s568,dec).
# [INFO] 0.535128076956454::activity(e2,s864,baseline).
# [INFO] 0.535289245334683::activity(e1,s366,inc).
# [INFO] 0.53579270979836::activity(e2,s702,inc).
# [INFO] 0.537510454534495::activity(e1,s782,baseline).
# [INFO] 0.53766990205746::activity(e3,s308,inc).
# [INFO] 0.540957172196354::activity(e1,s273,inc).
# [INFO] 0.54261367674744::activity(e2,s169,baseline).
# [INFO] 0.542723965192587::activity(e3,s309,dec).
# [INFO] 0.542876936299789::activity(e2,s740,baseline).
# [INFO] 0.543248126076089::activity(e2,s387,dec).
# [INFO] 0.543403386102814::activity(e3,s193,baseline).
# [INFO] 0.543413448682442::activity(e3,s442,dec).
# [INFO] 0.543835705896206::activity(e1,s733,dec).
# [INFO] 0.544210864414019::activity(e1,s458,dec).
# [INFO] 0.54432523880092::activity(e1,s959,dec).
# [INFO] 0.545326119286923::activity(e3,s302,baseline).
# [INFO] 0.545880445251752::activity(e3,s628,dec).
# [INFO] 0.546347168123795::activity(e2,s721,baseline).
# [INFO] 0.546530811517272::activity(e1,s41,dec).
# [INFO] 0.546723079932978::activity(e1,s167,baseline).
# [INFO] 0.546846764799045::activity(e3,s368,inc).
# [INFO] 0.547201918881043::activity(e3,s51,dec).
# [INFO] 0.547555649587938::activity(e3,s16,dec).
# [INFO] 0.547669458519807::activity(e3,s151,baseline).
# [INFO] 0.548125990671697::activity(e3,s419,dec).
# [INFO] 0.548207555217968::activity(e2,s62,dec).
# [INFO] 0.548239943869009::activity(e1,s558,dec).
# [INFO] 0.548693481260222::activity(e1,s528,baseline).
# [INFO] 0.548809506022064::activity(e2,s780,baseline).
# [INFO] 0.548894859814832::activity(e2,s346,baseline).
# [INFO] 0.550161826808336::activity(e3,s416,dec).
# [INFO] 0.551533132975559::activity(e3,s499,baseline).
# [INFO] 0.551777329858225::activity(e2,s585,dec).
# [INFO] 0.551783317699052::activity(e1,s952,inc).
# [INFO] 0.552234349221779::activity(e3,s729,baseline).
# [INFO] 0.552424033878287::activity(e3,s537,dec).
# [INFO] 0.552917024995287::activity(e3,s321,baseline).
# [INFO] 0.55333033673335::activity(e1,s613,inc).
# [INFO] 0.553857451105902::activity(e2,s876,baseline).
# [INFO] 0.553965303751799::activity(e2,s648,dec).
# [INFO] 0.554077628114713::activity(e2,s890,baseline).
# [INFO] 0.554267873252027::activity(e3,s95,inc).
# [INFO] 0.554637727835678::activity(e2,s494,inc).
# [INFO] 0.554760818280403::activity(e2,s684,inc).
# [INFO] 0.555210760623886::activity(e1,s521,dec).
# [INFO] 0.555441650010009::activity(e1,s369,inc).
# [INFO] 0.555652652976357::activity(e3,s750,inc).
# [INFO] 0.556305478890779::activity(e3,s803,baseline).
# [INFO] 0.556865021760808::activity(e1,s741,dec).
# [INFO] 0.557366866018345::activity(e2,s392,inc).
# [INFO] 0.558901334293041::activity(e3,s764,baseline).
# [INFO] 0.559297857665438::activity(e2,s903,inc).
# [INFO] 0.559659482140112::activity(e2,s518,dec).
# [INFO] 0.559701389231239::activity(e2,s959,inc).
# [INFO] 0.560021573369021::activity(e1,s510,inc).
# [INFO] 0.560190157208621::activity(e1,s405,inc).
# [INFO] 0.560220449176067::activity(e1,s446,inc).
# [INFO] 0.560398363061146::activity(e2,s257,inc).
# [INFO] 0.560508889856484::activity(e2,s713,dec).
# [INFO] 0.561251989881884::activity(e3,s271,baseline).
# [INFO] 0.561336435321306::activity(e3,s375,baseline).
# [INFO] 0.561989798524127::activity(e1,s174,baseline).
# [INFO] 0.562677132686121::activity(e1,s70,baseline).
# [INFO] 0.563447687461722::activity(e1,s346,inc).
# [INFO] 0.564656468737644::activity(e1,s803,dec).
# [INFO] 0.56476842715866::activity(e3,s984,inc).
# [INFO] 0.564980560512421::activity(e2,s302,dec).
# [INFO] 0.565285447956248::activity(e3,s433,baseline).
# [INFO] 0.56573521716664::activity(e3,s361,inc).
# [INFO] 0.566600076290192::activity(e3,s775,baseline).
# [INFO] 0.567815277919082::activity(e3,s913,inc).
# [INFO] 0.569008699758496::activity(e2,s94,dec).
# [INFO] 0.570012552130847::activity(e3,s274,inc).
# [INFO] 0.570374719981152::activity(e2,s638,inc).
# [INFO] 0.570955859688588::activity(e2,s723,inc).
# [INFO] 0.571653461375112::activity(e2,s295,inc).
# [INFO] 0.571658548962906::activity(e1,s311,baseline).
# [INFO] 0.571817391622835::activity(e1,s884,dec).
# [INFO] 0.572090675993947::activity(e2,s49,inc).
# [INFO] 0.572690584559907::activity(e2,s247,dec).
# [INFO] 0.573628797866893::activity(e3,s19,baseline).
# [INFO] 0.573954008704098::activity(e2,s235,dec).
# [INFO] 0.57511063632555::activity(e2,s924,dec).
# [INFO] 0.57532449697086::activity(e3,s458,dec).
# [INFO] 0.575554128285282::activity(e2,s503,dec).
# [INFO] 0.576336641733422::activity(e1,s72,dec).
# [INFO] 0.577187305985758::activity(e2,s428,baseline).
# [INFO] 0.577271842633547::activity(e1,s468,dec).
# [INFO] 0.577359666008523::activity(e3,s269,dec).
# [INFO] 0.577690588050337::activity(e3,s170,dec).
# [INFO] 0.57843681358286::activity(e3,s349,baseline).
# [INFO] 0.578778820234104::activity(e2,s627,baseline).
# [INFO] 0.580009339499397::activity(e2,s986,baseline).
# [INFO] 0.580726023008447::activity(e2,s703,baseline).
# [INFO] 0.580917879562177::activity(e3,s39,inc).
# [INFO] 0.581622459721704::activity(e3,s172,dec).
# [INFO] 0.583396058911083::activity(e2,s481,inc).
# [INFO] 0.583533142109163::activity(e3,s455,dec).
# [INFO] 0.584192641513153::activity(e2,s323,dec).
# [INFO] 0.584435570210316::activity(e3,s818,baseline).
# [INFO] 0.585250906539925::activity(e2,s707,baseline).
# [INFO] 0.586188117233085::activity(e3,s397,dec).
# [INFO] 0.586423283559184::activity(e1,s757,inc).
# [INFO] 0.587079273959778::activity(e3,s718,inc).
# [INFO] 0.587288982199381::activity(e3,s125,baseline).
# [INFO] 0.587699192191886::activity(e1,s818,dec).
# [INFO] 0.587724979226458::activity(e2,s432,dec).
# [INFO] 0.587911805665155::activity(e1,s576,dec).
# [INFO] 0.588193317492174::activity(e3,s29,baseline).
# [INFO] 0.589431332084015::activity(e3,s93,dec).
# [INFO] 0.591349972535924::activity(e1,s410,baseline).
# [INFO] 0.591674846772172::activity(e1,s93,dec).
# [INFO] 0.591751982398857::activity(e2,s294,inc).
# [INFO] 0.593534016440783::activity(e1,s899,dec).
# [INFO] 0.593745495277801::activity(e1,s348,dec).
# [INFO] 0.594222240717908::activity(e2,s289,inc).
# [INFO] 0.594472661271004::activity(e3,s627,inc).
# [INFO] 0.594572603148913::activity(e2,s367,baseline).
# [INFO] 0.595032203920452::activity(e3,s974,baseline).
# [INFO] 0.595137584751649::activity(e3,s610,dec).
# [INFO] 0.595157822275334::activity(e3,s313,inc).
# [INFO] 0.595537615631304::activity(e3,s381,inc).
# [INFO] 0.595730896026238::activity(e1,s761,inc).
# [INFO] 0.596227602349678::activity(e2,s237,baseline).
# [INFO] 0.597292926678295::activity(e3,s395,inc).
# [INFO] 0.598574852551138::activity(e2,s699,baseline).
# [INFO] 0.598751703400112::activity(e1,s217,inc).
# [INFO] 0.599148267281103::activity(e3,s34,baseline).
# [INFO] 0.60046970938808::activity(e1,s298,inc).
# [INFO] 0.601566222893815::activity(e3,s194,dec).
# [INFO] 0.602191910488323::activity(e3,s189,dec).
# [INFO] 0.602496093462863::activity(e2,s472,baseline).
# [INFO] 0.602568080448204::activity(e3,s113,dec).
# [INFO] 0.602667737921134::activity(e1,s283,inc).
# [INFO] 0.602733564236558::activity(e3,s405,dec).
# [INFO] 0.602787979314477::activity(e3,s430,inc).
# [INFO] 0.602833497803312::activity(e2,s795,inc).
# [INFO] 0.603082226246521::activity(e2,s667,inc).
# [INFO] 0.603825029893673::activity(e2,s681,baseline).
# [INFO] 0.603943440202637::activity(e1,s674,inc).
# [INFO] 0.607132378541987::activity(e2,s668,baseline).
# [INFO] 0.607294406002313::activity(e2,s343,baseline).
# [INFO] 0.607680546156852::activity(e1,s814,inc).
# [INFO] 0.607859086095008::activity(e1,s484,inc).
# [INFO] 0.607991603456686::activity(e3,s243,baseline).
# [INFO] 0.608793105432131::activity(e2,s430,inc).
# [INFO] 0.609956963060785::activity(e1,s646,dec).
# [INFO] 0.611486737417262::activity(e2,s814,baseline).
# [INFO] 0.612084176590481::activity(e3,s198,baseline).
# [INFO] 0.612233988033799::activity(e2,s88,dec).
# [INFO] 0.612662972977664::activity(e2,s223,baseline).
# [INFO] 0.613194804335735::activity(e3,s244,inc).
# [INFO] 0.613764134798763::activity(e2,s379,dec).
# [INFO] 0.61416232783877::activity(e2,s841,baseline).
# [INFO] 0.614252631164432::activity(e1,s840,baseline).
# [INFO] 0.614500974608472::activity(e1,s102,baseline).
# [INFO] 0.614690753096394::activity(e3,s898,inc).
# [INFO] 0.615332428063413::activity(e1,s78,baseline).
# [INFO] 0.615337888489368::activity(e1,s835,dec).
# [INFO] 0.615359475278328::activity(e2,s541,inc).
# [INFO] 0.616346220102836::activity(e2,s528,inc).
# [INFO] 0.616733082902912::activity(e1,s565,baseline).
# [INFO] 0.617012157727018::activity(e3,s236,inc).
# [INFO] 0.617204826401083::activity(e1,s140,dec).
# [INFO] 0.619328134642568::activity(e1,s51,dec).
# [INFO] 0.619460212003497::activity(e1,s962,inc).
# [INFO] 0.619597924244355::activity(e1,s1000,dec).
# [INFO] 0.620213103261864::activity(e1,s660,inc).
# [INFO] 0.620764466596155::activity(e3,s875,baseline).
# [INFO] 0.621277052460137::activity(e2,s229,dec).
# [INFO] 0.62152360205059::activity(e1,s89,dec).
# [INFO] 0.621966547855676::activity(e3,s166,inc).
# [INFO] 0.622052438506427::activity(e1,s181,inc).
# [INFO] 0.622490270984889::activity(e1,s851,baseline).
# [INFO] 0.625036986775893::activity(e3,s336,dec).
# [INFO] 0.625065402512683::activity(e1,s635,baseline).
# [INFO] 0.627486368006466::activity(e3,s602,baseline).
# [INFO] 0.627795234403362::activity(e1,s49,inc).
# [INFO] 0.628209976146102::activity(e1,s647,inc).
# [INFO] 0.629288331729278::activity(e1,s462,inc).
# [INFO] 0.630342101382802::activity(e2,s937,inc).
# [INFO] 0.630354514007834::activity(e1,s926,baseline).
# [INFO] 0.630474586524044::activity(e2,s984,dec).
# [INFO] 0.630806763369534::activity(e2,s185,inc).
# [INFO] 0.63164978647311::activity(e2,s159,dec).
# [INFO] 0.632160936598093::activity(e1,s374,inc).
# [INFO] 0.632786651334783::activity(e3,s268,dec).
# [INFO] 0.633062511488367::activity(e1,s747,baseline).
# [INFO] 0.633433712919507::activity(e2,s669,inc).
# [INFO] 0.633713299639691::activity(e1,s376,dec).
# [INFO] 0.633831900105441::activity(e2,s279,baseline).
# [INFO] 0.63447570949457::activity(e2,s910,baseline).
# [INFO] 0.6345163631447::activity(e1,s777,baseline).
# [INFO] 0.636188517061154::activity(e3,s662,baseline).
# [INFO] 0.636281309533033::activity(e2,s902,dec).
# [INFO] 0.636405522897148::activity(e1,s876,dec).
# [INFO] 0.636561012428635::activity(e1,s415,inc).
# [INFO] 0.636795332803547::activity(e2,s54,dec).
# [INFO] 0.637226773043827::activity(e2,s249,dec).
# [INFO] 0.637310500560015::activity(e1,s435,dec).
# [INFO] 0.638197962230126::activity(e2,s157,baseline).
# [INFO] 0.638236312864079::activity(e3,s443,baseline).
# [INFO] 0.638554868559751::activity(e3,s312,baseline).
# [INFO] 0.638575913457368::activity(e1,s836,inc).
# [INFO] 0.639875556609131::activity(e1,s889,baseline).
# [INFO] 0.640231687754752::activity(e3,s211,dec).
# [INFO] 0.640712784940701::activity(e2,s206,baseline).
# [INFO] 0.641029548461694::activity(e3,s104,baseline).
# [INFO] 0.641374634124693::activity(e1,s945,baseline).
# [INFO] 0.642213817673976::activity(e1,s538,dec).
# [INFO] 0.642346115562677::activity(e3,s586,inc).
# [INFO] 0.642378176236488::activity(e3,s970,baseline).
# [INFO] 0.643098048181254::activity(e2,s534,dec).
# [INFO] 0.643264874077424::activity(e2,s134,dec).
# [INFO] 0.644411727745685::activity(e1,s279,baseline).
# [INFO] 0.645813270127317::activity(e2,s331,inc).
# [INFO] 0.645900029678024::activity(e1,s315,baseline).
# [INFO] 0.646236944203371::activity(e2,s104,inc).
# [INFO] 0.646244094484847::activity(e1,s925,baseline).
# [INFO] 0.647762022353215::activity(e2,s262,inc).
# [INFO] 0.647767199408525::activity(e1,s397,baseline).
# [INFO] 0.648400891441832::activity(e1,s487,inc).
# [INFO] 0.64859715067567::activity(e2,s149,baseline).
# [INFO] 0.648738934819356::activity(e2,s544,dec).
# [INFO] 0.649006892843287::activity(e3,s372,dec).
# [INFO] 0.65012038842458::activity(e2,s163,baseline).
# [INFO] 0.650157417636802::activity(e2,s35,baseline).
# [INFO] 0.650352207542596::activity(e1,s304,baseline).
# [INFO] 0.650367057392597::activity(e3,s367,baseline).
# [INFO] 0.651238297413908::activity(e2,s732,dec).
# [INFO] 0.651251980180031::activity(e3,s365,inc).
# [INFO] 0.651927782777309::activity(e3,s27,baseline).
# [INFO] 0.652181838011186::activity(e2,s934,dec).
# [INFO] 0.654045791274112::activity(e3,s786,baseline).
# [INFO] 0.654716416750093::activity(e3,s330,inc).
# [INFO] 0.655080871879961::activity(e1,s709,inc).
# [INFO] 0.656864544389281::activity(e1,s133,inc).
# [INFO] 0.657570810652677::activity(e1,s30,inc).
# [INFO] 0.65795906160863::activity(e1,s729,inc).
# [INFO] 0.658069621776414::activity(e2,s629,dec).
# [INFO] 0.65855562154771::activity(e1,s792,baseline).
# [INFO] 0.658786608080678::activity(e2,s71,inc).
# [INFO] 0.658868499376968::activity(e1,s79,inc).
# [INFO] 0.659682351418927::activity(e3,s728,inc).
# [INFO] 0.660214777891837::activity(e3,s551,inc).
# [INFO] 0.661018018993217::activity(e3,s110,baseline).
# [INFO] 0.661320468381467::activity(e1,s616,baseline).
# [INFO] 0.661663852942054::activity(e1,s418,inc).
# [INFO] 0.662249302768471::activity(e3,s341,inc).
# [INFO] 0.662502748507069::activity(e3,s593,inc).
# [INFO] 0.663021325812345::activity(e3,s922,baseline).
# [INFO] 0.663820108792792::activity(e1,s846,inc).
# [INFO] 0.664424370216367::activity(e1,s601,baseline).
# [INFO] 0.664703404060805::activity(e2,s729,inc).
# [INFO] 0.665228422237193::activity(e3,s835,dec).
# [INFO] 0.665379108777235::activity(e3,s972,dec).
# [INFO] 0.665647051764769::activity(e1,s190,dec).
# [INFO] 0.665960082738529::activity(e3,s738,baseline).
# [INFO] 0.666607164779625::activity(e3,s290,dec).
# [INFO] 0.667437566351287::activity(e3,s967,dec).
# [INFO] 0.667473276766257::activity(e3,s391,dec).
# [INFO] 0.667679345025673::activity(e1,s573,baseline).
# [INFO] 0.667904121100013::activity(e2,s706,inc).
# [INFO] 0.669412227653403::activity(e2,s311,dec).
# [INFO] 0.669690989549077::activity(e2,s360,dec).
# [INFO] 0.670022692139457::activity(e1,s47,inc).
# [INFO] 0.670276555304527::activity(e1,s357,dec).
# [INFO] 0.670325166112174::activity(e2,s142,baseline).
# [INFO] 0.670550156990775::activity(e2,s372,baseline).
# [INFO] 0.671107889647471::activity(e2,s234,inc).
# [INFO] 0.67140521551767::activity(e2,s304,baseline).
# [INFO] 0.671548309729511::activity(e2,s848,dec).
# [INFO] 0.673696348915611::activity(e1,s730,inc).
# [INFO] 0.673935469077001::activity(e1,s766,baseline).
# [INFO] 0.674126147727754::activity(e1,s389,dec).
# [INFO] 0.674421623624561::activity(e2,s9,baseline).
# [INFO] 0.676856710378744::activity(e2,s56,inc).
# [INFO] 0.677196419394089::activity(e2,s712,dec).
# [INFO] 0.67746266345319::activity(e1,s269,inc).
# [INFO] 0.677797806146696::activity(e2,s268,baseline).
# [INFO] 0.677958901459656::activity(e2,s4,inc).
# [INFO] 0.678090760616953::activity(e3,s854,baseline).
# [INFO] 0.679037538964272::activity(e1,s108,baseline).
# [INFO] 0.679372065840789::activity(e2,s764,baseline).
# [INFO] 0.680598812198999::activity(e1,s157,dec).
# ...
# [INFO] 0.893982478210062::fold_change(p0,s433,baseline).
# [INFO] 0.894326667080552::fold_change(p0,s982,dec).
# [INFO] 0.89451883142176::fold_change(p0,s951,baseline).
# [INFO] 0.895055015383237::fold_change(p0,s258,baseline).
# [INFO] 0.895508161379843::fold_change(p0,s201,inc).
# [INFO] 0.896765098266961::fold_change(p0,s884,dec).
# [INFO] 0.896985300490527::fold_change(p0,s248,dec).
# [INFO] 0.897205272131099::fold_change(p0,s423,dec).
# [INFO] 0.897694067581674::fold_change(p0,s563,dec).
# [INFO] 0.897720360925874::fold_change(p0,s181,baseline).
# [INFO] 0.898031816380084::fold_change(p0,s692,inc).
# [INFO] 0.898960959236175::fold_change(p0,s572,dec).
# [INFO] 0.89902266119936::fold_change(p0,s525,dec).
# [INFO] 0.89935991017367::fold_change(p0,s195,inc).
# [INFO] 0.899721106016155::fold_change(p0,s261,inc).
# [INFO] 0.899750784264597::fold_change(p0,s235,dec).
# [INFO] 0.899791308989676::fold_change(p0,s640,dec).
# [INFO] 0.899866310795314::fold_change(p0,s809,dec).
# [INFO] 0.899936033152139::fold_change(p0,s120,dec).
# [INFO] 0.901318122550344::fold_change(p0,s223,inc).
# [INFO] 0.901714544514814::fold_change(p0,s311,dec).
# [INFO] 0.901727259059668::fold_change(p0,s682,inc).
# [INFO] 0.901987264811312::fold_change(p0,s987,baseline).
# [INFO] 0.902192746630772::fold_change(p0,s288,baseline).
# [INFO] 0.902553595820429::fold_change(p0,s978,baseline).
# [INFO] 0.903452795702519::fold_change(p0,s660,dec).
# [INFO] 0.903890136574754::fold_change(p0,s172,inc).
# [INFO] 0.904428272686452::fold_change(p0,s853,baseline).
# [INFO] 0.904591649982161::fold_change(p0,s25,dec).
# [INFO] 0.905002517263766::fold_change(p0,s632,dec).
# [INFO] 0.905956965150621::fold_change(p0,s34,dec).
# [INFO] 0.905982974592847::fold_change(p0,s643,dec).
# [INFO] 0.906070122064315::fold_change(p0,s319,baseline).
# [INFO] 0.906764551726743::fold_change(p0,s768,baseline).
# [INFO] 0.907119814801548::fold_change(p0,s875,inc).
# [INFO] 0.907354448730157::fold_change(p0,s614,dec).
# [INFO] 0.909999376071047::fold_change(p0,s668,baseline).
# [INFO] 0.910223100224113::fold_change(p0,s289,dec).
# [INFO] 0.910227806807549::fold_change(p0,s791,inc).
# [INFO] 0.910306263368464::fold_change(p0,s297,inc).
# [INFO] 0.910438698706392::fold_change(p0,s115,dec).
# [INFO] 0.912182523627159::fold_change(p0,s662,inc).
# [INFO] 0.912306654607265::fold_change(p0,s975,inc).
# [INFO] 0.912580454226872::fold_change(p0,s419,baseline).
# [INFO] 0.913431995905287::fold_change(p0,s946,inc).
# [INFO] 0.913477840997546::fold_change(p0,s395,dec).
# [INFO] 0.914196277834759::fold_change(p0,s266,baseline).
# [INFO] 0.9148241112649::fold_change(p0,s346,dec).
# [INFO] 0.915191113506307::fold_change(p0,s615,dec).
# [INFO] 0.915460713951936::fold_change(p0,s274,baseline).
# [INFO] 0.915524112752389::fold_change(p0,s182,inc).
# [INFO] 0.915568098534581::fold_change(p0,s679,inc).
# [INFO] 0.915951568176642::fold_change(p0,s646,baseline).
# [INFO] 0.916187186767935::fold_change(p0,s247,baseline).
# [INFO] 0.917254088647259::fold_change(p0,s233,baseline).
# [INFO] 0.918980350138845::fold_change(p0,s243,dec).
# [INFO] 0.919568256240031::fold_change(p0,s677,dec).
# [INFO] 0.920023060731433::fold_change(p0,s821,baseline).
# [INFO] 0.922097158386527::fold_change(p0,s502,baseline).
# [INFO] 0.922338596298995::fold_change(p0,s300,inc).
# [INFO] 0.922753519925723::fold_change(p0,s538,inc).
# [INFO] 0.922799567151063::fold_change(p0,s655,baseline).
# [INFO] 0.922837176104957::fold_change(p0,s208,inc).
# [INFO] 0.923163256417952::fold_change(p0,s9,inc).
# [INFO] 0.923457734761493::fold_change(p0,s75,baseline).
# [INFO] 0.923460202892765::fold_change(p0,s796,inc).
# [INFO] 0.923749366725672::fold_change(p0,s971,inc).
# [INFO] 0.924253888391463::fold_change(p0,s803,dec).
# [INFO] 0.924475636707629::fold_change(p0,s811,inc).
# [INFO] 0.925296753741293::fold_change(p0,s321,inc).
# [INFO] 0.925474419502477::fold_change(p0,s466,baseline).
# [INFO] 0.926000710159744::fold_change(p0,s732,inc).
# [INFO] 0.926197829461436::fold_change(p0,s387,inc).
# [INFO] 0.926213391046742::fold_change(p0,s665,inc).
# [INFO] 0.926755906578467::fold_change(p0,s959,inc).
# [INFO] 0.927130485438899::fold_change(p0,s72,baseline).
# [INFO] 0.927511318394925::fold_change(p0,s555,baseline).
# [INFO] 0.928172697605953::fold_change(p0,s78,inc).
# [INFO] 0.928247490325289::fold_change(p0,s613,dec).
# [INFO] 0.928500325415786::fold_change(p0,s900,baseline).
# [INFO] 0.928567370936094::fold_change(p0,s924,baseline).
# [INFO] 0.928907969353025::fold_change(p0,s163,inc).
# [INFO] 0.929091384072186::fold_change(p0,s333,inc).
# [INFO] 0.929264021152533::fold_change(p0,s926,inc).
# [INFO] 0.929933084515656::fold_change(p0,s244,inc).
# [INFO] 0.929967319929516::fold_change(p0,s582,dec).
# [INFO] 0.930046371239011::fold_change(p0,s949,dec).
# [INFO] 0.930118005437752::fold_change(p0,s342,inc).
# [INFO] 0.930252956626007::fold_change(p0,s699,inc).
# [INFO] 0.930722639121987::fold_change(p0,s869,baseline).
# [INFO] 0.930945945201476::fold_change(p0,s366,dec).
# [INFO] 0.932478103368563::fold_change(p0,s216,baseline).
# [INFO] 0.932799614823448::fold_change(p0,s740,baseline).
# [INFO] 0.932981139401823::fold_change(p0,s326,inc).
# [INFO] 0.933022545271618::fold_change(p0,s345,dec).
# [INFO] 0.93345815080441::fold_change(p0,s706,dec).
# [INFO] 0.934159111727826::fold_change(p0,s622,dec).
# [INFO] 0.934174446197755::fold_change(p0,s476,dec).
# [INFO] 0.934553276886245::fold_change(p0,s122,baseline).
# [INFO] 0.935728847460859::fold_change(p0,s352,inc).
# [INFO] 0.936396064961013::fold_change(p0,s795,dec).
# [INFO] 0.93695880816142::fold_change(p0,s434,baseline).
# [INFO] 0.937255715000994::fold_change(p0,s375,baseline).
# [INFO] 0.937362273320647::fold_change(p0,s773,inc).
# [INFO] 0.938055768185167::fold_change(p0,s545,dec).
# [INFO] 0.938703482946613::fold_change(p0,s405,baseline).
# [INFO] 0.938965696551801::fold_change(p0,s149,baseline).
# [INFO] 0.940200663818138::fold_change(p0,s535,dec).
# [INFO] 0.940569846991383::fold_change(p0,s222,baseline).
# [INFO] 0.940655495714359::fold_change(p0,s966,inc).
# [INFO] 0.941278899082373::fold_change(p0,s707,dec).
# [INFO] 0.941403735817011::fold_change(p0,s785,inc).
# [INFO] 0.941955276209394::fold_change(p0,s180,inc).
# [INFO] 0.942232037947004::fold_change(p0,s637,dec).
# [INFO] 0.942831337708852::fold_change(p0,s275,inc).
# [INFO] 0.942989067285124::fold_change(p0,s852,dec).
# [INFO] 0.943200345520845::fold_change(p0,s400,inc).
# [INFO] 0.943233148721592::fold_change(p0,s755,inc).
# [INFO] 0.9440569965296::fold_change(p0,s239,dec).
# [INFO] 0.944134928354348::fold_change(p0,s626,baseline).
# [INFO] 0.94467782981425::fold_change(p0,s452,dec).
# [INFO] 0.946959432152167::fold_change(p0,s123,inc).
# [INFO] 0.947347289561653::fold_change(p0,s445,dec).
# [INFO] 0.948110458086617::fold_change(p0,s367,dec).
# [INFO] 0.949286891261659::fold_change(p0,s415,dec).
# [INFO] 0.949909254314965::fold_change(p0,s146,inc).
# [INFO] 0.950156076242019::fold_change(p0,s964,dec).
# [INFO] 0.95045261526024::fold_change(p0,s134,dec).
# [INFO] 0.950968229851738::fold_change(p0,s889,dec).
# [INFO] 0.951268739329731::fold_change(p0,s775,dec).
# [INFO] 0.951552787429617::fold_change(p0,s184,inc).
# [INFO] 0.951801068550766::fold_change(p0,s335,inc).
# [INFO] 0.95234719180233::fold_change(p0,s55,baseline).
# [INFO] 0.952974896217361::fold_change(p0,s426,baseline).
# [INFO] 0.953054769836125::fold_change(p0,s280,dec).
# [INFO] 0.953087361677273::fold_change(p0,s899,inc).
# [INFO] 0.953457794924547::fold_change(p0,s557,inc).
# [INFO] 0.954791807138421::fold_change(p0,s526,inc).
# [INFO] 0.954972479424007::fold_change(p0,s252,inc).
# [INFO] 0.955044818730397::fold_change(p0,s66,inc).
# [INFO] 0.955070661987589::fold_change(p0,s485,inc).
# [INFO] 0.95521222523765::fold_change(p0,s984,inc).
# [INFO] 0.955475014496481::fold_change(p0,s2,inc).
# [INFO] 0.955525420790798::fold_change(p0,s595,dec).
# [INFO] 0.955709155480773::fold_change(p0,s373,dec).
# [INFO] 0.956104994301755::fold_change(p0,s175,dec).
# [INFO] 0.956152140591842::fold_change(p0,s700,baseline).
# [INFO] 0.956351545310392::fold_change(p0,s51,inc).
# [INFO] 0.956745224270639::fold_change(p0,s359,dec).
# [INFO] 0.957292034623653::fold_change(p0,s251,baseline).
# [INFO] 0.957794546877962::fold_change(p0,s178,dec).
# [INFO] 0.959258133392448::fold_change(p0,s990,dec).
# [INFO] 0.959623583036191::fold_change(p0,s368,inc).
# [INFO] 0.959714432659758::fold_change(p0,s661,dec).
# [INFO] 0.959728737946769::fold_change(p0,s857,baseline).
# [INFO] 0.959788595575724::fold_change(p0,s357,baseline).
# [INFO] 0.959830902602368::fold_change(p0,s103,dec).
# [INFO] 0.959836244961096::fold_change(p0,s594,dec).
# [INFO] 0.959913148615015::fold_change(p0,s902,dec).
# [INFO] 0.960309108664228::fold_change(p0,s441,dec).
# [INFO] 0.96044606394424::fold_change(p0,s128,dec).
# [INFO] 0.96060886512635::fold_change(p0,s320,inc).
# [INFO] 0.960666307448776::fold_change(p0,s138,baseline).
# [INFO] 0.960876408622337::fold_change(p0,s154,dec).
# [INFO] 0.960979383146032::fold_change(p0,s826,inc).
# [INFO] 0.961460934979861::fold_change(p0,s962,dec).
# [INFO] 0.961565507668196::fold_change(p0,s631,inc).
# [INFO] 0.961570665255768::fold_change(p0,s649,dec).
# [INFO] 0.962154699937944::fold_change(p0,s528,dec).
# [INFO] 0.962546474325861::fold_change(p0,s442,baseline).
# [INFO] 0.962742888284535::fold_change(p0,s544,inc).
# [INFO] 0.963564742340705::fold_change(p0,s606,dec).
# [INFO] 0.963754763121227::fold_change(p0,s234,inc).
# [INFO] 0.96463159708176::fold_change(p0,s576,dec).
# [INFO] 0.964878819497416::fold_change(p0,s135,inc).
# [INFO] 0.964928651394345::fold_change(p0,s102,dec).
# [INFO] 0.965094483922686::fold_change(p0,s427,inc).
# [INFO] 0.965646839895936::fold_change(p0,s489,baseline).
# [INFO] 0.965748833724824::fold_change(p0,s956,inc).
# [INFO] 0.966222825886586::fold_change(p0,s268,baseline).
# [INFO] 0.96739411812978::fold_change(p0,s527,baseline).
# [INFO] 0.967700144671486::fold_change(p0,s810,inc).
# [INFO] 0.968698687301618::fold_change(p0,s110,dec).
# [INFO] 0.969716671001265::fold_change(p0,s603,dec).
# [INFO] 0.970145152440291::fold_change(p0,s718,inc).
# [INFO] 0.970456048592107::fold_change(p0,s756,inc).
# [INFO] 0.971305747914783::fold_change(p0,s841,inc).
# [INFO] 0.971740103587253::fold_change(p0,s461,baseline).
# [INFO] 0.97226614330319::fold_change(p0,s996,baseline).
# [INFO] 0.973084207053453::fold_change(p0,s784,inc).
# [INFO] 0.973932724011237::fold_change(p0,s602,dec).
# [INFO] 0.974260211278569::fold_change(p0,s815,inc).
# [INFO] 0.974496307071246::fold_change(p0,s348,baseline).
# [INFO] 0.974528277532009::fold_change(p0,s228,dec).
# [INFO] 0.974711504981754::fold_change(p0,s1,inc).
# [INFO] 0.97476089167607::fold_change(p0,s374,inc).
# [INFO] 0.975734725783065::fold_change(p0,s789,inc).
# [INFO] 0.976503149227477::fold_change(p0,s491,dec).
# [INFO] 0.977339722148796::fold_change(p0,s20,inc).
# [INFO] 0.977415144470204::fold_change(p0,s82,dec).
# [INFO] 0.97781323138743::fold_change(p0,s870,baseline).
# [INFO] 0.977967037068844::fold_change(p0,s42,baseline).
# [INFO] 0.978821023147613::fold_change(p0,s133,dec).
# [INFO] 0.978840761318053::fold_change(p0,s220,baseline).
# [INFO] 0.97927969828805::fold_change(p0,s644,baseline).
# [INFO] 0.979317750866915::fold_change(p0,s905,dec).
# [INFO] 0.979715647184434::fold_change(p0,s31,dec).
# [INFO] 0.979763232059034::fold_change(p0,s11,dec).
# [INFO] 0.980125614263297::fold_change(p0,s747,dec).
# [INFO] 0.980547858475606::fold_change(p0,s769,dec).
# [INFO] 0.980804473281812::fold_change(p0,s298,dec).
# [INFO] 0.980944815066373::fold_change(p0,s392,dec).
# [INFO] 0.980974520727996::fold_change(p0,s336,dec).
# [INFO] 0.981371787707458::fold_change(p0,s932,inc).
# [INFO] 0.982077366891734::fold_change(p0,s963,dec).
# [INFO] 0.982108826376752::fold_change(p0,s118,inc).
# [INFO] 0.982459721936141::fold_change(p0,s908,dec).
# [INFO] 0.982476660655459::fold_change(p0,s315,dec).
# [INFO] 0.982629789006844::fold_change(p0,s903,dec).
# [INFO] 0.982644643468416::fold_change(p0,s566,dec).
# [INFO] 0.982949336333162::fold_change(p0,s394,inc).
# [INFO] 0.983198553868609::fold_change(p0,s273,dec).
# [INFO] 0.983537751062532::fold_change(p0,s45,dec).
# [INFO] 0.983539586002053::fold_change(p0,s338,baseline).
# [INFO] 0.983568172724411::fold_change(p0,s142,dec).
# [INFO] 0.98405762971398::fold_change(p0,s688,baseline).
# [INFO] 0.98560811996809::fold_change(p0,s167,inc).
# [INFO] 0.985693562027117::fold_change(p0,s513,baseline).
# [INFO] 0.98648517453142::fold_change(p0,s198,dec).
# [INFO] 0.987163088157249::fold_change(p0,s28,baseline).
# [INFO] 0.987775095529368::fold_change(p0,s568,baseline).
# [INFO] 0.988016589782166::fold_change(p0,s558,inc).
# [INFO] 0.988447432878457::fold_change(p0,s912,dec).
# [INFO] 0.988801069642434::fold_change(p0,s231,baseline).
# [INFO] 0.988803041824461::fold_change(p0,s968,inc).
# [INFO] 0.988892759110889::fold_change(p0,s230,inc).
# [INFO] 0.989001794003863::fold_change(p0,s43,dec).
# [INFO] 0.989044209694586::fold_change(p0,s372,dec).
# [INFO] 0.989531818236168::fold_change(p0,s428,dec).
# [INFO] 0.989603915009679::fold_change(p0,s948,inc).
# [INFO] 0.9896777050544::fold_change(p0,s728,baseline).
# [INFO] 0.989721225000034::fold_change(p0,s349,inc).
# [INFO] 0.989794694434512::fold_change(p0,s882,inc).
# [INFO] 0.989969204550852::fold_change(p0,s256,baseline).
# [INFO] 0.990992732955377::fold_change(p0,s779,dec).
# [INFO] 0.992155741704044::fold_change(p0,s764,dec).
# [INFO] 0.992425544044342::fold_change(p0,s422,dec).
# [INFO] 0.992803677317515::fold_change(p0,s591,baseline).
# [INFO] 0.992899098306633::fold_change(p0,s541,dec).
# [INFO] 0.993859958430284::fold_change(p0,s734,dec).
# [INFO] 0.994608740506678::fold_change(p0,s505,baseline).
# [INFO] 0.994958178951487::fold_change(p0,s695,inc).
# [INFO] 0.995049893615589::fold_change(p0,s58,dec).
# [INFO] 0.995532292360474::fold_change(p0,s86,inc).
# [INFO] 0.995555109324688::fold_change(p0,s766,baseline).
# [INFO] 0.996417903594385::fold_change(p0,s628,dec).
# [INFO] 0.996865676230932::fold_change(p0,s792,inc).
# [INFO] 0.996989719436174::fold_change(p0,s397,baseline).
# [INFO] 0.99706691121622::fold_change(p0,s836,baseline).
# [INFO] 0.997469275645693::fold_change(p0,s294,dec).
# [INFO] 0.997775368188463::fold_change(p0,s804,dec).
# [INFO] 0.998005157698643::fold_change(p0,s793,inc).
# [INFO] 0.99837969840387::fold_change(p0,s670,inc).
# [INFO] 0.998415617505944::fold_change(p0,s156,inc).
# [INFO] 0.998662763101396::fold_change(p0,s74,dec).
# [INFO] 0.998673006771521::fold_change(p0,s578,baseline).
# [INFO] 0.999781177537432::fold_change(p0,s312,dec).
# [INFO]
# -132.71715609536972 [0.99999998, 0.0, 1.759e-05, 2e-08, 3.63e-06, 0.99996913, 0.0, 0.99999637, 1.328e-05, 0.99497306, 0.98325855, 0.50323723, 0.06945421, 0.02257169, 0.34357162, 0.33936739, 0.0032346, 0.7634726, 0.18025371, 0.00036998, 0.01065398, 0.80420056, 0.93686995, 0.34852593, 0.06375475, 0.94727247, 0.07196179, 0.00608747, 0.00465696, 0.31650906, 0.12634523, 0.04055836, 0.30790245, 0.59687786, 0.04949293, 0.16456562] [t(0.33,inc)::occupancy(P,S,inc), t(0.33,baseline)::occupancy(P,S,inc), t(0.33,dec)::occupancy(P,S,inc), t(0.33,inc)::occupancy(P,S,dec), t(0.33,baseline)::occupancy(P,S,dec), t(0.33,dec)::occupancy(P,S,dec), t(0.33,inc)::occupancy(P,S,baseline), t(0.33,baseline)::occupancy(P,S,baseline), t(0.33,dec)::occupancy(P,S,baseline), t(0.33,e2,inc)::occupancy(P,S,inc), t(0.33,e3,inc)::occupancy(P,S,inc), t(0.33,e1,baseline)::occupancy(P,S,inc), t(0.33,e1,dec)::occupancy(P,S,inc), t(0.33,e3,dec)::occupancy(P,S,inc), t(0.33,e2,baseline)::occupancy(P,S,inc), t(0.33,e3,baseline)::occupancy(P,S,inc), t(0.33,e2,dec)::occupancy(P,S,inc), t(0.33,e1,inc)::occupancy(P,S,inc), t(0.33,e1,baseline)::occupancy(P,S,dec), t(0.33,e2,inc)::occupancy(P,S,dec), t(0.33,e3,inc)::occupancy(P,S,dec), t(0.33,e1,dec)::occupancy(P,S,dec), t(0.33,e3,dec)::occupancy(P,S,dec), t(0.33,e2,baseline)::occupancy(P,S,dec), t(0.33,e3,baseline)::occupancy(P,S,dec), t(0.33,e2,dec)::occupancy(P,S,dec), t(0.33,e1,inc)::occupancy(P,S,dec), t(0.33,e3,inc)::occupancy(P,S,baseline), t(0.33,e2,inc)::occupancy(P,S,baseline), t(0.33,e1,baseline)::occupancy(P,S,baseline), t(0.33,e1,dec)::occupancy(P,S,baseline), t(0.33,e3,dec)::occupancy(P,S,baseline), t(0.33,e2,baseline)::occupancy(P,S,baseline), t(0.33,e3,baseline)::occupancy(P,S,baseline), t(0.33,e2,dec)::occupancy(P,S,baseline), t(0.33,e1,inc)::occupancy(P,S,baseline)] 20

# %% [markdown]
# Testing

# %%
# Testing
model_trained = f'{EXP_DIR}model_trained.pl'
test = ['training', 'testing']
PATH_TO_TRUTH = f'data/processed/synthetic_data/model_A1/n1000/'
results = {}

# %%
for test_on in test:
    PATH_TO_TESTING = f'{EXP_DIR}{test_on}/'
    compare_to = [test_on, 'truth']
    for compare in compare_to:
        if compare == 'truth':
            path_to_truth = PATH_TO_TRUTH
        else: 
            path_to_truth = PATH_TO_TESTING

        test_results = test_model.main(
            experiment = EXPERIMENT, 
            path_to_data = PATH_TO_TESTING, 
            path_to_truth = path_to_truth, 
            model_trained = model_trained, 
            targets = ['occupancy', 'modification'], 
            test_on = test_on, compare = compare, 
            mode = 'inference')
        results[f'{test_on}_vs_{compare}'] = test_results
# Out:
# Inferring data (s1)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s1)...
# Inferring data (s1000)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s1000)...
# Inferring data (s102)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s102)...
# Inferring data (s103)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s103)...
# Inferring data (s104)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s104)...
# Inferring data (s105)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s105)...
# Inferring data (s106)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s106)...
# Inferring data (s107)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s107)...
# Inferring data (s108)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s108)...
# Inferring data (s11)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s11)...
# Inferring data (s110)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s110)...
# Inferring data (s111)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s111)...
# Inferring data (s112)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s112)...
# Inferring data (s113)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s113)...
# Inferring data (s114)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s114)...
# Inferring data (s115)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s115)...
# Inferring data (s116)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s116)...
# Inferring data (s118)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s118)...
# Inferring data (s119)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s119)...
# Inferring data (s120)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s120)...
# Inferring data (s121)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s121)...
# Inferring data (s122)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s122)...
# Inferring data (s123)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s123)...
# Inferring data (s124)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s124)...
# Inferring data (s125)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s125)...
# Inferring data (s128)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s128)...
# Inferring data (s13)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s13)...
# Inferring data (s130)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s130)...
# Inferring data (s131)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s131)...
# Inferring data (s132)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s132)...
# Inferring data (s133)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s133)...
# Inferring data (s134)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s134)...
# Inferring data (s135)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s135)...
# Inferring data (s136)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s136)...
# Inferring data (s137)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s137)...
# Inferring data (s138)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s138)...
# Inferring data (s14)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s14)...
# Inferring data (s140)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s140)...
# Inferring data (s142)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s142)...
# Inferring data (s146)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s146)...
# Inferring data (s147)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s147)...
# Inferring data (s148)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s148)...
# Inferring data (s149)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s149)...
# Inferring data (s15)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s15)...
# Inferring data (s150)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s150)...
# Inferring data (s151)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s151)...
# Inferring data (s152)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s152)...
# Inferring data (s153)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s153)...
# Inferring data (s154)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s154)...
# Inferring data (s156)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s156)...
# Inferring data (s157)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s157)...
# Inferring data (s158)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s158)...
# Inferring data (s159)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s159)...
# Inferring data (s16)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s16)...
# Inferring data (s161)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s161)...
# Inferring data (s162)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s162)...
# Inferring data (s163)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s163)...
# Inferring data (s164)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s164)...
# Inferring data (s166)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s166)...
# Inferring data (s167)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s167)...
# Inferring data (s168)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s168)...
# Inferring data (s169)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s169)...
# Inferring data (s17)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s17)...
# Inferring data (s170)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s170)...
# Inferring data (s171)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s171)...
# Inferring data (s172)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s172)...
# Inferring data (s174)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s174)...
# Inferring data (s175)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s175)...
# Inferring data (s176)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s176)...
# Inferring data (s177)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s177)...
# Inferring data (s178)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s178)...
# Inferring data (s179)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s179)...
# Inferring data (s18)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s18)...
# Inferring data (s180)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s180)...
# Inferring data (s181)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s181)...
# Inferring data (s182)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s182)...
# Inferring data (s184)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s184)...
# Inferring data (s185)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s185)...
# Inferring data (s186)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s186)...
# Inferring data (s188)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s188)...
# Inferring data (s189)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s189)...
# Inferring data (s19)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s19)...
# Inferring data (s190)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s190)...
# Inferring data (s191)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s191)...
# Inferring data (s193)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s193)...
# Inferring data (s194)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s194)...
# Inferring data (s195)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s195)...
# Inferring data (s196)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s196)...
# Inferring data (s197)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s197)...
# Inferring data (s198)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s198)...
# Inferring data (s199)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s199)...
# Inferring data (s2)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s2)...
# Inferring data (s20)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s20)...
# Inferring data (s200)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s200)...
# Inferring data (s201)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s201)...
# Inferring data (s204)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s204)...
# Inferring data (s205)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s205)...
# Inferring data (s206)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s206)...
# Inferring data (s207)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s207)...
# Inferring data (s208)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s208)...
# Inferring data (s209)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s209)...
# Inferring data (s21)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s21)...
# Inferring data (s211)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s211)...
# Inferring data (s214)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s214)...
# Inferring data (s215)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s215)...
# Inferring data (s216)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s216)...
# Inferring data (s217)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s217)...
# Inferring data (s218)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s218)...
# Inferring data (s219)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s219)...
# Inferring data (s22)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s22)...
# Inferring data (s220)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s220)...
# Inferring data (s221)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s221)...
# Inferring data (s222)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s222)...
# Inferring data (s223)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s223)...
# Inferring data (s224)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s224)...
# Inferring data (s225)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s225)...
# Inferring data (s226)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s226)...
# Inferring data (s228)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s228)...
# Inferring data (s229)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s229)...
# Inferring data (s23)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s23)...
# Inferring data (s230)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s230)...
# Inferring data (s231)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s231)...
# Inferring data (s232)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s232)...
# Inferring data (s233)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s233)...
# Inferring data (s234)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s234)...
# Inferring data (s235)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s235)...
# Inferring data (s236)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s236)...
# Inferring data (s237)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s237)...
# Inferring data (s239)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s239)...
# Inferring data (s24)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s24)...
# Inferring data (s240)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s240)...
# Inferring data (s241)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s241)...
# Inferring data (s243)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s243)...
# Inferring data (s244)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s244)...
# Inferring data (s246)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s246)...
# Inferring data (s247)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s247)...
# Inferring data (s248)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s248)...
# Inferring data (s249)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s249)...
# Inferring data (s25)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s25)...
# Inferring data (s251)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s251)...
# Inferring data (s252)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s252)...
# Inferring data (s253)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s253)...
# Inferring data (s254)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s254)...
# Inferring data (s256)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s256)...
# Inferring data (s257)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s257)...
# Inferring data (s258)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s258)...
# Inferring data (s259)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s259)...
# Inferring data (s26)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s26)...
# Inferring data (s260)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s260)...
# Inferring data (s261)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s261)...
# Inferring data (s262)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s262)...
# Inferring data (s263)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s263)...
# Inferring data (s266)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s266)...
# Inferring data (s267)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s267)...
# Inferring data (s268)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s268)...
# Inferring data (s269)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s269)...
# Inferring data (s27)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s27)...
# Inferring data (s270)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s270)...
# Inferring data (s271)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s271)...
# Inferring data (s273)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s273)...
# Inferring data (s274)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s274)...
# Inferring data (s275)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s275)...
# Inferring data (s276)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s276)...
# Inferring data (s277)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s277)...
# Inferring data (s278)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s278)...
# Inferring data (s279)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s279)...
# Inferring data (s28)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s28)...
# Inferring data (s280)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s280)...
# Inferring data (s282)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s282)...
# Inferring data (s283)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s283)...
# Inferring data (s284)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s284)...
# Inferring data (s285)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s285)...
# Inferring data (s286)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s286)...
# Inferring data (s288)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s288)...
# Inferring data (s289)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s289)...
# Inferring data (s29)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s29)...
# Inferring data (s290)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s290)...
# Inferring data (s291)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s291)...
# Inferring data (s292)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s292)...
# Inferring data (s294)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s294)...
# Inferring data (s295)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s295)...
# Inferring data (s296)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s296)...
# Inferring data (s297)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s297)...
# Inferring data (s298)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s298)...
# Inferring data (s299)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s299)...
# Inferring data (s30)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s30)...
# Inferring data (s300)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s300)...
# Inferring data (s301)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s301)...
# Inferring data (s302)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s302)...
# Inferring data (s303)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s303)...
# Inferring data (s304)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s304)...
# Inferring data (s305)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s305)...
# Inferring data (s306)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s306)...
# Inferring data (s308)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s308)...
# Inferring data (s309)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s309)...
# Inferring data (s31)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s31)...
# Inferring data (s310)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s310)...
# Inferring data (s311)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s311)...
# Inferring data (s312)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s312)...
# Inferring data (s313)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s313)...
# Inferring data (s315)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s315)...
# Inferring data (s317)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s317)...
# Inferring data (s319)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s319)...
# Inferring data (s32)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s32)...
# Inferring data (s320)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s320)...
# Inferring data (s321)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s321)...
# Inferring data (s322)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s322)...
# Inferring data (s323)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s323)...
# Inferring data (s324)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s324)...
# Inferring data (s325)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s325)...
# Inferring data (s326)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s326)...
# Inferring data (s328)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s328)...
# Inferring data (s330)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s330)...
# Inferring data (s331)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s331)...
# Inferring data (s332)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s332)...
# Inferring data (s333)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s333)...
# Inferring data (s334)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s334)...
# Inferring data (s335)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s335)...
# Inferring data (s336)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s336)...
# Inferring data (s337)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s337)...
# Inferring data (s338)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s338)...
# Inferring data (s34)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s34)...
# Inferring data (s340)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s340)...
# Inferring data (s341)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s341)...
# Inferring data (s342)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s342)...
# Inferring data (s343)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s343)...
# Inferring data (s345)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s345)...
# Inferring data (s346)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s346)...
# Inferring data (s348)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s348)...
# Inferring data (s349)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s349)...
# Inferring data (s35)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s35)...
# Inferring data (s350)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s350)...
# Inferring data (s351)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s351)...
# Inferring data (s352)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s352)...
# Inferring data (s357)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s357)...
# Inferring data (s358)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s358)...
# Inferring data (s359)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s359)...
# Inferring data (s36)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s36)...
# Inferring data (s360)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s360)...
# Inferring data (s361)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s361)...
# Inferring data (s364)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s364)...
# Inferring data (s365)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s365)...
# Inferring data (s366)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s366)...
# Inferring data (s367)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s367)...
# Inferring data (s368)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s368)...
# Inferring data (s369)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s369)...
# Inferring data (s372)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s372)...
# Inferring data (s373)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s373)...
# Inferring data (s374)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s374)...
# Inferring data (s375)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s375)...
# Inferring data (s376)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s376)...
# Inferring data (s378)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s378)...
# Inferring data (s379)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s379)...
# Inferring data (s38)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s38)...
# Inferring data (s381)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s381)...
# Inferring data (s382)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s382)...
# Inferring data (s385)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s385)...
# Inferring data (s386)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s386)...
# Inferring data (s387)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s387)...
# Inferring data (s388)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s388)...
# Inferring data (s389)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s389)...
# Inferring data (s39)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s39)...
# Inferring data (s390)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s390)...
# Inferring data (s391)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s391)...
# Inferring data (s392)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s392)...
# Inferring data (s394)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s394)...
# Inferring data (s395)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s395)...
# Inferring data (s396)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s396)...
# Inferring data (s397)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s397)...
# Inferring data (s4)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s4)...
# Inferring data (s400)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s400)...
# Inferring data (s401)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s401)...
# Inferring data (s404)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s404)...
# Inferring data (s405)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s405)...
# Inferring data (s407)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s407)...
# Inferring data (s408)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s408)...
# Inferring data (s409)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s409)...
# Inferring data (s41)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s41)...
# Inferring data (s410)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s410)...
# Inferring data (s411)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s411)...
# Inferring data (s413)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s413)...
# Inferring data (s414)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s414)...
# Inferring data (s415)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s415)...
# Inferring data (s416)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s416)...
# Inferring data (s417)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s417)...
# Inferring data (s418)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s418)...
# Inferring data (s419)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s419)...
# Inferring data (s42)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s42)...
# Inferring data (s420)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s420)...
# Inferring data (s422)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s422)...
# Inferring data (s423)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s423)...
# Inferring data (s425)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s425)...
# Inferring data (s426)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s426)...
# Inferring data (s427)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s427)...
# Inferring data (s428)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s428)...
# Inferring data (s429)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s429)...
# Inferring data (s43)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s43)...
# Inferring data (s430)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s430)...
# Inferring data (s432)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s432)...
# Inferring data (s433)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s433)...
# Inferring data (s434)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s434)...
# Inferring data (s435)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s435)...
# Inferring data (s436)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s436)...
# Inferring data (s438)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s438)...
# Inferring data (s44)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s44)...
# Inferring data (s440)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s440)...
# Inferring data (s441)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s441)...
# Inferring data (s442)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s442)...
# Inferring data (s443)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s443)...
# Inferring data (s444)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s444)...
# Inferring data (s445)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s445)...
# Inferring data (s446)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s446)...
# Inferring data (s448)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s448)...
# Inferring data (s449)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s449)...
# Inferring data (s45)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s45)...
# Inferring data (s450)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s450)...
# Inferring data (s451)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s451)...
# Inferring data (s452)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s452)...
# Inferring data (s453)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s453)...
# Inferring data (s455)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s455)...
# Inferring data (s456)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s456)...
# Inferring data (s458)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s458)...
# Inferring data (s459)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s459)...
# Inferring data (s46)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s46)...
# Inferring data (s461)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s461)...
# Inferring data (s462)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s462)...
# Inferring data (s463)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s463)...
# Inferring data (s466)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s466)...
# Inferring data (s467)...
# problog ./models/mh15/test_on_training.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s467)...
# Inferring data (s468)...
# ...
# Finished inference (s506)...
# Inferring data (s519)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s519)...
# Inferring data (s522)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s522)...
# Inferring data (s523)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s523)...
# Inferring data (s529)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s529)...
# Inferring data (s53)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s53)...
# Inferring data (s530)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s530)...
# Inferring data (s540)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s540)...
# Inferring data (s542)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s542)...
# Inferring data (s543)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s543)...
# Inferring data (s547)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s547)...
# Inferring data (s554)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s554)...
# Inferring data (s559)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s559)...
# Inferring data (s560)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s560)...
# Inferring data (s561)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s561)...
# Inferring data (s562)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s562)...
# Inferring data (s57)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s57)...
# Inferring data (s575)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s575)...
# Inferring data (s577)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s577)...
# Inferring data (s588)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s588)...
# Inferring data (s589)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s589)...
# Inferring data (s59)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s59)...
# Inferring data (s598)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s598)...
# Inferring data (s599)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s599)...
# Inferring data (s600)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s600)...
# Inferring data (s604)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s604)...
# Inferring data (s61)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s61)...
# Inferring data (s612)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s612)...
# Inferring data (s620)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s620)...
# Inferring data (s623)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s623)...
# Inferring data (s624)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s624)...
# Inferring data (s63)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s63)...
# Inferring data (s630)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s630)...
# Inferring data (s636)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s636)...
# Inferring data (s639)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s639)...
# Inferring data (s642)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s642)...
# Inferring data (s654)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s654)...
# Inferring data (s656)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s656)...
# Inferring data (s659)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s659)...
# Inferring data (s67)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s67)...
# Inferring data (s68)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s68)...
# Inferring data (s683)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s683)...
# Inferring data (s685)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s685)...
# Inferring data (s689)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s689)...
# Inferring data (s694)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s694)...
# Inferring data (s698)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s698)...
# Inferring data (s704)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s704)...
# Inferring data (s705)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s705)...
# Inferring data (s710)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s710)...
# Inferring data (s720)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s720)...
# Inferring data (s722)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s722)...
# Inferring data (s724)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s724)...
# Inferring data (s725)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s725)...
# Inferring data (s727)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s727)...
# Inferring data (s744)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s744)...
# Inferring data (s746)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s746)...
# Inferring data (s748)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s748)...
# Inferring data (s759)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s759)...
# Inferring data (s76)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s76)...
# Inferring data (s760)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s760)...
# Inferring data (s763)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s763)...
# Inferring data (s767)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s767)...
# Inferring data (s771)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s771)...
# Inferring data (s772)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s772)...
# Inferring data (s790)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s790)...
# Inferring data (s797)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s797)...
# Inferring data (s799)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s799)...
# Inferring data (s80)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s80)...
# Inferring data (s800)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s800)...
# Inferring data (s801)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s801)...
# Inferring data (s805)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s805)...
# Inferring data (s816)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s816)...
# Inferring data (s822)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s822)...
# Inferring data (s825)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s825)...
# Inferring data (s83)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s83)...
# Inferring data (s830)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s830)...
# Inferring data (s831)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s831)...
# Inferring data (s833)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s833)...
# Inferring data (s834)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s834)...
# Inferring data (s839)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s839)...
# Inferring data (s847)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s847)...
# Inferring data (s849)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s849)...
# Inferring data (s861)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s861)...
# Inferring data (s865)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s865)...
# Inferring data (s866)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s866)...
# Inferring data (s867)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s867)...
# Inferring data (s887)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s887)...
# Inferring data (s892)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s892)...
# Inferring data (s893)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s893)...
# Inferring data (s894)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s894)...
# Inferring data (s907)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s907)...
# Inferring data (s923)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s923)...
# Inferring data (s929)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s929)...
# Inferring data (s931)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s931)...
# Inferring data (s939)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s939)...
# Inferring data (s942)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s942)...
# Inferring data (s943)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s943)...
# Inferring data (s950)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s950)...
# Inferring data (s955)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s955)...
# Inferring data (s961)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s961)...
# Inferring data (s965)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s965)...
# Inferring data (s97)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s97)...
# Inferring data (s973)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s973)...
# Inferring data (s976)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s976)...
# Inferring data (s98)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s98)...
# Inferring data (s980)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s980)...
# Inferring data (s983)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s983)...
# Inferring data (s99)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s99)...
# Inferring data (s993)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s993)...
# Inferring data (s994)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s994)...
# Inferring data (s995)...
# problog ./models/mh15/test_on_testing.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s995)...

# %%
PATH_TO_TESTING = f'{EXP_DIR}testing/'
predictions = predict_model.main(
    experiment = EXPERIMENT, 
    path_to_data = PATH_TO_TESTING, 
    model_trained = model_trained, 
    targets = ['occupancy', 'modification'], 
    mode = 'inference', infer_from = 'facts',
    suffix = '_testing')
results['predictions'] = predictions
# Out:
# Inferring data (s10)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s10)...
# Inferring data (s100)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s100)...
# Inferring data (s101)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s101)...
# Inferring data (s109)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s109)...
# Inferring data (s117)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s117)...
# Inferring data (s12)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s12)...
# Inferring data (s126)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s126)...
# Inferring data (s127)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s127)...
# Inferring data (s129)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s129)...
# Inferring data (s139)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s139)...
# Inferring data (s141)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s141)...
# Inferring data (s143)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s143)...
# Inferring data (s144)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s144)...
# Inferring data (s145)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s145)...
# Inferring data (s155)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s155)...
# Inferring data (s160)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s160)...
# Inferring data (s165)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s165)...
# Inferring data (s173)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s173)...
# Inferring data (s183)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s183)...
# Inferring data (s187)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s187)...
# Inferring data (s192)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s192)...
# Inferring data (s202)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s202)...
# Inferring data (s203)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s203)...
# Inferring data (s210)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s210)...
# Inferring data (s212)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s212)...
# Inferring data (s213)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s213)...
# Inferring data (s227)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s227)...
# Inferring data (s238)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s238)...
# Inferring data (s242)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s242)...
# Inferring data (s245)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s245)...
# Inferring data (s250)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s250)...
# Inferring data (s255)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s255)...
# Inferring data (s264)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s264)...
# Inferring data (s265)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s265)...
# Inferring data (s272)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s272)...
# Inferring data (s281)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s281)...
# Inferring data (s287)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s287)...
# Inferring data (s293)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s293)...
# Inferring data (s3)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s3)...
# Inferring data (s307)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s307)...
# Inferring data (s314)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s314)...
# Inferring data (s316)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s316)...
# Inferring data (s318)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s318)...
# Inferring data (s327)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s327)...
# Inferring data (s329)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s329)...
# Inferring data (s33)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s33)...
# Inferring data (s339)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s339)...
# Inferring data (s344)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s344)...
# Inferring data (s347)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s347)...
# Inferring data (s353)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s353)...
# Inferring data (s354)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s354)...
# Inferring data (s355)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s355)...
# Inferring data (s356)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s356)...
# Inferring data (s362)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s362)...
# Inferring data (s363)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s363)...
# Inferring data (s37)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s37)...
# Inferring data (s370)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s370)...
# Inferring data (s371)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s371)...
# Inferring data (s377)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s377)...
# Inferring data (s380)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s380)...
# Inferring data (s383)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s383)...
# Inferring data (s384)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s384)...
# Inferring data (s393)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s393)...
# Inferring data (s398)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s398)...
# Inferring data (s399)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s399)...
# Inferring data (s40)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s40)...
# Inferring data (s402)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s402)...
# Inferring data (s403)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s403)...
# Inferring data (s406)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s406)...
# Inferring data (s412)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s412)...
# Inferring data (s421)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s421)...
# Inferring data (s424)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s424)...
# Inferring data (s431)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s431)...
# Inferring data (s437)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s437)...
# Inferring data (s439)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s439)...
# Inferring data (s447)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s447)...
# Inferring data (s454)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s454)...
# Inferring data (s457)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s457)...
# Inferring data (s460)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s460)...
# Inferring data (s464)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s464)...
# Inferring data (s465)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s465)...
# Inferring data (s478)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s478)...
# Inferring data (s480)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s480)...
# Inferring data (s483)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s483)...
# Inferring data (s486)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s486)...
# Inferring data (s490)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s490)...
# Inferring data (s496)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s496)...
# Inferring data (s498)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s498)...
# Inferring data (s50)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s50)...
# Inferring data (s506)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s506)...
# Inferring data (s519)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s519)...
# Inferring data (s522)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s522)...
# Inferring data (s523)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s523)...
# Inferring data (s529)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s529)...
# Inferring data (s53)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s53)...
# Inferring data (s530)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s530)...
# Inferring data (s540)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s540)...
# Inferring data (s542)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s542)...
# Inferring data (s543)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s543)...
# Inferring data (s547)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s547)...
# Inferring data (s554)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s554)...
# Inferring data (s559)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s559)...
# Inferring data (s560)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s560)...
# Inferring data (s561)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s561)...
# Inferring data (s562)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s562)...
# Inferring data (s57)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s57)...
# Inferring data (s575)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s575)...
# Inferring data (s577)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s577)...
# Inferring data (s588)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s588)...
# Inferring data (s589)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s589)...
# Inferring data (s59)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s59)...
# Inferring data (s598)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s598)...
# Inferring data (s599)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s599)...
# Inferring data (s600)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s600)...
# Inferring data (s604)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s604)...
# Inferring data (s61)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s61)...
# Inferring data (s612)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s612)...
# Inferring data (s620)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s620)...
# Inferring data (s623)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s623)...
# Inferring data (s624)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s624)...
# Inferring data (s63)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s63)...
# Inferring data (s630)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s630)...
# Inferring data (s636)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s636)...
# Inferring data (s639)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s639)...
# Inferring data (s642)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s642)...
# Inferring data (s654)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s654)...
# Inferring data (s656)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s656)...
# Inferring data (s659)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s659)...
# Inferring data (s67)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s67)...
# Inferring data (s68)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s68)...
# Inferring data (s683)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s683)...
# Inferring data (s685)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s685)...
# Inferring data (s689)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s689)...
# Inferring data (s694)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s694)...
# Inferring data (s698)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s698)...
# Inferring data (s704)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s704)...
# Inferring data (s705)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s705)...
# Inferring data (s710)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s710)...
# Inferring data (s720)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s720)...
# Inferring data (s722)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s722)...
# Inferring data (s724)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s724)...
# Inferring data (s725)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s725)...
# Inferring data (s727)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s727)...
# Inferring data (s744)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s744)...
# Inferring data (s746)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s746)...
# Inferring data (s748)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s748)...
# Inferring data (s759)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s759)...
# Inferring data (s76)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s76)...
# Inferring data (s760)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s760)...
# Inferring data (s763)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s763)...
# Inferring data (s767)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s767)...
# Inferring data (s771)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s771)...
# Inferring data (s772)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s772)...
# Inferring data (s790)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s790)...
# Inferring data (s797)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s797)...
# Inferring data (s799)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s799)...
# Inferring data (s80)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s80)...
# Inferring data (s800)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s800)...
# Inferring data (s801)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s801)...
# Inferring data (s805)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s805)...
# Inferring data (s816)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s816)...
# Inferring data (s822)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s822)...
# Inferring data (s825)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s825)...
# Inferring data (s83)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s83)...
# Inferring data (s830)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s830)...
# Inferring data (s831)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s831)...
# Inferring data (s833)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s833)...
# Inferring data (s834)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s834)...
# Inferring data (s839)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s839)...
# Inferring data (s847)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s847)...
# Inferring data (s849)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s849)...
# Inferring data (s861)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s861)...
# Inferring data (s865)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s865)...
# Inferring data (s866)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s866)...
# Inferring data (s867)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s867)...
# Inferring data (s887)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s887)...
# Inferring data (s892)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s892)...
# Inferring data (s893)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s893)...
# Inferring data (s894)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s894)...
# Inferring data (s907)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s907)...
# Inferring data (s923)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s923)...
# Inferring data (s929)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s929)...
# Inferring data (s931)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s931)...
# Inferring data (s939)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s939)...
# Inferring data (s942)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s942)...
# Inferring data (s943)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s943)...
# Inferring data (s950)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s950)...
# Inferring data (s955)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s955)...
# Inferring data (s961)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s961)...
# Inferring data (s965)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s965)...
# Inferring data (s97)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s97)...
# Inferring data (s973)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s973)...
# Inferring data (s976)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s976)...
# Inferring data (s98)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s98)...
# Inferring data (s980)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s980)...
# Inferring data (s983)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s983)...
# Inferring data (s99)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s99)...
# Inferring data (s993)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s993)...
# Inferring data (s994)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s994)...
# Inferring data (s995)...
# problog ./models/mh15/make_predictions.pl -o ./models/mh15/predictions/inferred_example.txt
# Finished inference (s995)...

# %%
with open(f'{EXP_DIR}results.pickle', 'wb') as file:
    pickle.dump(results, file, protocol=pickle.HIGHEST_PROTOCOL)
