# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.visualization import visualize

# %%
os.chdir('/home/mhuebner/Desktop/bezzlab/research/projects/phospho_pi/')

# %%
MODEL = 'model_A1'
REPORTS_DIR = f'./reports/figures/{MODEL}'
# create a directory to save the figure in reports/figures called modelA1 if it does not exist
if not os.path.exists(REPORTS_DIR):
    os.makedirs(REPORTS_DIR)

# %%
# import all the pickle files in the models folder   
results_dict = visualize.import_pickles('./models/')

# %%
experiments = {'mh02': ['exp1', 'exp2', 'exp3', 'exp4']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of facts/evidence during lfi on predicting {compare} ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh02_facts_evidence_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
group_x = {'mh02': ['exp1', 'exp2', 'exp3', 'exp4']}
group_y = {'mh02': ['exp1', 'exp2', 'exp3', 'exp4']}

metric = 'dob'
outpath = f'{REPORTS_DIR}/mh02_facts_evidence_prob_corr_testing_{metric}.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=False, figsize=(9, 9), metric = metric)

# %%
experiments = {'mh01': [],
               'mh04': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of noisy data on predicting {compare} ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh04_noisydata_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
group_x = {'mh04': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
group_y = {'mh01': []}

metric = 'dob'
outpath = f'{REPORTS_DIR}/mh04_noisydata_prob_corr_testing_{metric}.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=True, figsize=(9, 3), metric = metric)

# %%
experiments = {'mh01': [],
               'mh04': ['m1_20', 'm2_20', 'm3_20', 'm4_20', 'm5_20', 'm6_20', 'm7_20']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of noisy data on predicting {compare} ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh04_noisydata_{metric}_{data}_vs_{vs}_part2.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
group_x = {'mh04': ['m1_20', 'm2_20', 'm3_20', 'm4_20', 'm5_20', 'm6_20', 'm7_20']}
group_y = {'mh01': []}

metric = 'dob'
outpath = f'{REPORTS_DIR}/mh04_noisydata_prob_corr_testing_{metric}_part2.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=True, figsize=(9, 3), metric = metric)
# Out:
# /home/mhuebner/anaconda3/envs/phospho_pi/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,

# %%
experiments = {'mh03': [],
               'mh09': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
data = 'testing'
vs = 'testing'
compare = 'occupancy'
metric = 'n_pred'
title = f'Impact of noisy data on predicting {compare} with noisy-or ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh09_noisyor_noisydata_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
group_x = {'mh09': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
group_y = {'mh03': []}

metric = 'dob_norm'
outpath = f'{REPORTS_DIR}/mh09_noisyor_noisydata_prob_corr_testing_{metric}.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=False, figsize=(9, 3), metric = metric)

# %%
group_x = {'mh09': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
group_y = {'mh04': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}

metric = 'dob'
outpath = f'{REPORTS_DIR}/mh04_mh09_noisyor_noisydata_prob_corr_testing_{metric}.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=True, figsize=(9, 9), metric = metric)

# %%
experiments = {'mh05': ['n50', 'n100', 'n250', 'n500', 'n1000']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of # of samples on predicting {compare} ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh05_nsamples_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
experiments = {'mh10': ['n50', 'n100', 'n250', 'n500', 'n1000']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of # of samples on predicting {compare} with noisy-or ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh10_noisyor_nsamples_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
experiments = {'mh01': [],
               'mh06': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of missing data on predicting {compare} ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh06_missingdata_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
experiments = {'mh03': [],
               'mh11': ['m1_0.1', 'm1_1', 'm1_5', 'm1_10', 'm1_20']}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of missing data on predicting {compare} with noisy-or ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh11_noisyor_missingdata_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
experiments = {'mh04': ['m1_20'],
               'mh07': [],
               'mh08': []}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of prob facts on predicting {compare} ({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh07_mh08_probfacts_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
group_x = {'mh04': ['m1_20'],
           'mh07': [],
           'mh08': []}
group_y = {'mh04': ['m1_20'],
           'mh07': [],
           'mh08': []}

metric = 'dob'
outpath = f'{REPORTS_DIR}/mh07_mh08_probfacts_prob_corr_testing_{metric}.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=False, figsize=(9, 9), metric = metric)

# %%
experiments = {'mh04': ['m1_20'],
               'mh09': ['m1_20'],
               'mh12': []}
data = 'testing'
vs = 'truth'
compare = 'occupancy'
metric = 'accuracy'
title = f'Impact of prob facts on predicting {compare} with noisyor({data} vs. {vs})'
outpath = f'{REPORTS_DIR}/mh12_noisyor_probfacts_{metric}_{data}_vs_{vs}.png'

# %%
visualize.plot_model_metric(results_dict, experiments, data, vs, compare, metric, title, outpath)

# %%
group_x = {'mh04': ['m1_20'],
           'mh09': ['m1_20'],
           'mh12': []}
group_y = {'mh04': ['m1_20'],
           'mh09': ['m1_20'],
           'mh12': []}

metric = 'dob_norm'
outpath = f'{REPORTS_DIR}/mh12_noisyor_probfacts_prob_corr_testing_{metric}.png'

visualize.compare_prob_corr_plots(results_dict, group_x, group_y, outpath, logistic=False, figsize=(9, 9), metric = metric)
